# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/INTERNSHIP_VIHARA/PROJECT2/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_9'
validation_data_path = '/content/Split_data/Validation/Group_9'

# %%
os.listdir(training_data_path)
# Out:
# ['kulfi', 'masala_dosa', 'momos']

# %%
os.listdir(validation_data_path)
# Out:
# ['kulfi', 'masala_dosa', 'momos']

# %%
os.listdir(training_data_path+'/kulfi')
# Out:
# ['154.jpg',
#  '088.jpg',
#  '033.jpg',
#  'images (13).jpg',
#  '027.jpg',
#  '234.jpg',
#  '073.jpg',
#  '186.jpg',
#  '178.jpg',
#  '147.jpg',
#  '053.jpg',
#  'images (3).jpg',
#  '069.jpg',
#  '080.jpg',
#  '054.jpg',
#  '172.jpg',
#  '041.jpg',
#  '142.jpg',
#  'images (18).jpg',
#  '135.jpg',
#  '102.jpg',
#  '227.jpg',
#  '226.jpg',
#  '176.jpg',
#  '038.jpg',
#  '137.jpg',
#  '162.jpg',
#  'download (2).jpg',
#  '134.jpg',
#  '222.jpg',
#  'images (21).jpg',
#  '078.jpg',
#  '002.jpg',
#  '158.jpg',
#  '196.jpg',
#  '005.jpg',
#  '205.jpg',
#  '024.jpg',
#  '209.jpg',
#  '199.jpg',
#  'images (2).jpg',
#  '059.jpg',
#  '163.jpg',
#  '161.jpg',
#  '037.jpg',
#  '155.jpg',
#  '168.jpg',
#  '140.jpg',
#  '201.jpg',
#  '177.jpg',
#  'images (15).jpg',
#  'images (22).jpg',
#  '015.jpg',
#  '117.jpg',
#  '203.jpg',
#  'images (5).jpg',
#  'download.jpg',
#  '104.jpg',
#  '072.jpg',
#  '044.jpg',
#  '030.jpg',
#  '106.jpg',
#  '050.jpg',
#  '001.jpg',
#  '219.jpg',
#  '087.jpg',
#  '119.jpg',
#  'images (4).jpg',
#  '212.jpg',
#  'images (14).jpg',
#  '062.jpg',
#  '013.jpg',
#  '031.jpg',
#  '174.jpg',
#  '213.jpg',
#  '103.jpg',
#  '018.jpg',
#  '003.jpg',
#  '006.jpg',
#  '100.jpg',
#  '202.jpg',
#  '214.jpg',
#  'download (1).jpg',
#  '036.jpg',
#  'images (1).jpg',
#  '166.jpg',
#  '063.jpg',
#  '098.jpg',
#  '012.jpg',
#  '184.jpg',
#  '237.jpg',
#  '064.jpg',
#  '113.jpg',
#  '040.jpg',
#  '091.jpg',
#  '004.jpg',
#  '220.jpg',
#  '111.jpg',
#  '217.jpg',
#  '195.jpg',
#  '017.jpg',
#  '099.jpg',
#  '115.jpg',
#  '131.jpg',
#  '236.jpg',
#  '183.jpg',
#  '228.jpg',
#  '068.jpg',
#  '230.jpg',
#  '089.jpg',
#  '109.jpg',
#  '181.jpg',
#  '215.jpg',
#  '150.jpg',
#  '208.jpg',
#  '075.jpg',
#  '194.jpg',
#  '023.jpg',
#  '198.jpg',
#  '105.jpg']

# %%
os.listdir(training_data_path+'/masala_dosa')
# Out:
# ['243.jpg',
#  '088.jpg',
#  '046.jpg',
#  '027.jpg',
#  '058.jpg',
#  '265.jpg',
#  '070.jpg',
#  '186.jpg',
#  '275.jpg',
#  '260.jpg',
#  'download (3).jpg',
#  '048.jpg',
#  '255.jpg',
#  'images (3).jpg',
#  '069.jpg',
#  '307.jpg',
#  '041.jpg',
#  '142.jpg',
#  '278.jpg',
#  '221.jpg',
#  '135.jpg',
#  '129.jpg',
#  '246.jpg',
#  '226.jpg',
#  '188.jpg',
#  '235.jpg',
#  '067.jpg',
#  '222.jpg',
#  '216.jpg',
#  '297.jpg',
#  '078.jpg',
#  '002.jpg',
#  '158.jpg',
#  '196.jpg',
#  '009.jpg',
#  '005.jpg',
#  '171.jpg',
#  'images.jpg',
#  '021.jpg',
#  '302.jpg',
#  '045.jpg',
#  'images (17).jpg',
#  '199.jpg',
#  'images (2).jpg',
#  '224.jpg',
#  '146.jpg',
#  '059.jpg',
#  'images (7).jpg',
#  '161.jpg',
#  '182.jpg',
#  '077.jpg',
#  '155.jpg',
#  '266.jpg',
#  '123.jpg',
#  '151.jpg',
#  'images (15).jpg',
#  '015.jpg',
#  '117.jpg',
#  '128.jpg',
#  '049.jpg',
#  '159.jpg',
#  'images (5).jpg',
#  'download.jpg',
#  '271.jpg',
#  '030.jpg',
#  '108.jpg',
#  '272.jpg',
#  '013.jpg',
#  'download (6).jpg',
#  '279.jpg',
#  '165.jpg',
#  '031.jpg',
#  '190.jpg',
#  '018.jpg',
#  '296.jpg',
#  '003.jpg',
#  '200.jpg',
#  '169.jpg',
#  '202.jpg',
#  '051.jpg',
#  '081.jpg',
#  '020.jpg',
#  '294.jpg',
#  'download (1).jpg',
#  '036.jpg',
#  'images (1).jpg',
#  '166.jpg',
#  '063.jpg',
#  '085.jpg',
#  '012.jpg',
#  '160.jpg',
#  '229.jpg',
#  '092.jpg',
#  '127.jpg',
#  '111.jpg',
#  '032.jpg',
#  '017.jpg',
#  '144.jpg',
#  'images (12).jpg',
#  '094.jpg',
#  'images (19).jpg',
#  '269.jpg',
#  '052.jpg',
#  'images (10).jpg',
#  '249.jpg',
#  '293.jpg',
#  'images (8).jpg',
#  '204.jpg',
#  '251.jpg',
#  '101.jpg',
#  '007.jpg',
#  '284.jpg',
#  '295.jpg',
#  '240.jpg',
#  '132.jpg',
#  '194.jpg',
#  '262.jpg',
#  '292.jpg',
#  '270.jpg',
#  '105.jpg']

# %%
plt.figure(figsize=(5,3))
plt.title('momos')
Baked_potato = plt.imread(training_data_path + '/momos/018.jpg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('masala_dosa')
Donut = plt.imread(training_data_path + '/masala_dosa/003.jpg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
group9_path = os.path.join(training_data_path)
labels = sorted([name for name in os.listdir(group9_path)
                 if os.path.isdir(os.path.join(group9_path, name))])
print("Group_9 Classes:", labels)
# Out:
# Group_9 Classes: ['kulfi', 'masala_dosa', 'momos']

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 20)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3

model = Sequential([
    Conv2D(32, (3,3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(256,256,3)),
                     BatchNormalization(),
                     MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
                      Dropout(0.3),
    Dense(num_classes, activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    16,777,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,871,875 (64.36 MB)
#  Trainable params: 16,871,427 (64.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.4726 - loss: 3.0861 - val_accuracy: 0.3667 - val_loss: 1.3706
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 75s 4s/step - accuracy: 0.6323 - loss: 1.7134 - val_accuracy: 0.4417 - val_loss: 1.1908
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - accuracy: 0.6461 - loss: 1.0183 - val_accuracy: 0.4667 - val_loss: 1.2377
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - accuracy: 0.7036 - loss: 0.6496 - val_accuracy: 0.4167 - val_loss: 1.5814
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.7630 - loss: 0.5307 - val_accuracy: 0.4417 - val_loss: 1.9315
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.7834 - loss: 0.4533 - val_accuracy: 0.4333 - val_loss: 1.7844
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 67s 4s/step - accuracy: 0.7723 - loss: 0.4597 - val_accuracy: 0.3250 - val_loss: 2.8118
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.8158 - loss: 0.4498 - val_accuracy: 0.3250 - val_loss: 3.3012
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.8686 - loss: 0.3513 - val_accuracy: 0.4000 - val_loss: 3.0067
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 67s 4s/step - accuracy: 0.8736 - loss: 0.3208 - val_accuracy: 0.4083 - val_loss: 2.7288
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.8523 - loss: 0.3939 - val_accuracy: 0.4333 - val_loss: 2.7023
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.8516 - loss: 0.3169 - val_accuracy: 0.4250 - val_loss: 2.8358
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.8603 - loss: 0.3509 - val_accuracy: 0.4833 - val_loss: 2.4515
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 65s 4s/step - accuracy: 0.8358 - loss: 0.3690 - val_accuracy: 0.5667 - val_loss: 2.1997
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 64s 4s/step - accuracy: 0.9082 - loss: 0.2392 - val_accuracy: 0.4583 - val_loss: 2.4553
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.8864 - loss: 0.2997 - val_accuracy: 0.5250 - val_loss: 1.8651
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.9257 - loss: 0.2698 - val_accuracy: 0.5417 - val_loss: 1.8116
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - accuracy: 0.8886 - loss: 0.2613 - val_accuracy: 0.5333 - val_loss: 1.7835
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9107 - loss: 0.1917 - val_accuracy: 0.6000 - val_loss: 1.6308
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9393 - loss: 0.1468 - val_accuracy: 0.5917 - val_loss: 1.8138
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9344 - loss: 0.1688 - val_accuracy: 0.5000 - val_loss: 2.2363
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.9329 - loss: 0.1784 - val_accuracy: 0.5667 - val_loss: 2.5160
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - accuracy: 0.9240 - loss: 0.2366 - val_accuracy: 0.5583 - val_loss: 2.3304
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9161 - loss: 0.1789 - val_accuracy: 0.6000 - val_loss: 1.5470
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9574 - loss: 0.1236 - val_accuracy: 0.6583 - val_loss: 1.4438
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9344 - loss: 0.1872 - val_accuracy: 0.5833 - val_loss: 2.0985
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - accuracy: 0.9549 - loss: 0.1711 - val_accuracy: 0.5917 - val_loss: 1.6708
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.9340 - loss: 0.1740 - val_accuracy: 0.6583 - val_loss: 1.2249
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9538 - loss: 0.1084 - val_accuracy: 0.6417 - val_loss: 1.4861
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.9735 - loss: 0.0697 - val_accuracy: 0.6500 - val_loss: 1.3201
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - accuracy: 0.9732 - loss: 0.0788 - val_accuracy: 0.6083 - val_loss: 1.5122
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.9769 - loss: 0.0673 - val_accuracy: 0.6417 - val_loss: 1.5852
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.9425 - loss: 0.1390 - val_accuracy: 0.6167 - val_loss: 1.3456
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9752 - loss: 0.0897 - val_accuracy: 0.6250 - val_loss: 1.4804
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - accuracy: 0.9244 - loss: 0.1376 - val_accuracy: 0.6333 - val_loss: 1.3443
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.9565 - loss: 0.2237 - val_accuracy: 0.6333 - val_loss: 1.3410
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - accuracy: 0.9296 - loss: 0.2376 - val_accuracy: 0.6250 - val_loss: 1.4522
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9696 - loss: 0.0948 - val_accuracy: 0.5833 - val_loss: 1.5653
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9729 - loss: 0.1154 - val_accuracy: 0.6000 - val_loss: 1.4489
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9497 - loss: 0.1404 - val_accuracy: 0.6083 - val_loss: 1.6499
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9582 - loss: 0.1275 - val_accuracy: 0.5667 - val_loss: 1.8417
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9680 - loss: 0.1098 - val_accuracy: 0.6583 - val_loss: 1.3802
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 67s 4s/step - accuracy: 0.9530 - loss: 0.1200 - val_accuracy: 0.6750 - val_loss: 1.3310
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.9709 - loss: 0.1058 - val_accuracy: 0.6083 - val_loss: 1.6104
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.9630 - loss: 0.1422 - val_accuracy: 0.6333 - val_loss: 1.4684
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.9666 - loss: 0.0957 - val_accuracy: 0.6333 - val_loss: 1.3938
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.9785 - loss: 0.0732 - val_accuracy: 0.6333 - val_loss: 1.3349
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9620 - loss: 0.0961 - val_accuracy: 0.6500 - val_loss: 1.5783
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9869 - loss: 0.0379 - val_accuracy: 0.6250 - val_loss: 1.5948
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 69s 4s/step - accuracy: 0.9814 - loss: 0.0492 - val_accuracy: 0.6250 - val_loss: 1.8247

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['kulfi', 'masala_dosa', 'momos']

# %%
train_input_data.class_indices
# Out:
# {'kulfi': 0, 'masala_dosa': 1, 'momos': 2}

# %%
def fun(path):
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # Load and preprocess the image
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # Predict using the model
    pred = model.predict(input_image)

    # Mapping only for Group_1 (train_input_data created from Group_1 folder)
    mapping = train_input_data.class_indices  # Automatically has only 3 classes
    inv_map = {v: k for k, v in mapping.items()}

    # Get predicted class index and label
    predicted_index = np.argmax(pred)
    predicted_label = inv_map[predicted_index]

    # Print for debugging
    print("Group_1 class mapping:", mapping)
    print("Model raw output:", pred)
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}")

    # Display image with prediction
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Split_data/Train/Group_9/masala_dosa/002.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Group_1 class mapping: {'kulfi': 0, 'masala_dosa': 1, 'momos': 2}
# Model raw output: [[3.4412648e-09 1.0000000e+00 2.1432944e-08]]
# Predicted class index: 1
# Predicted label: masala_dosa

# %%
fun('/content/Split_data/Train/Group_9/kulfi/001.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Group_1 class mapping: {'kulfi': 0, 'masala_dosa': 1, 'momos': 2}
# Model raw output: [[1.0000000e+00 2.8881336e-10 2.0069112e-10]]
# Predicted class index: 0
# Predicted label: kulfi

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_9'

# %%
labels = ['kulfi', 'masala_dosa', 'momos']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 303ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        kulfi       0.75      0.53      0.62        40
#  masala_dosa       0.66      0.82      0.73        40
#        momos       0.67      0.70      0.68        40
#
#     accuracy                           0.68       120
#    macro avg       0.69      0.68      0.68       120
# weighted avg       0.69      0.68      0.68       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.6833

# %%
model.save('/content/train_group9.h5')
print("Model saved successfully at /content/custom_food_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully at /content/custom_food_model.h5

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/train_group9.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
