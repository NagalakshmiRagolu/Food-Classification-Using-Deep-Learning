# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/INTERNSHIP_VIHARA/PROJECT2/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_7'
validation_data_path = '/content/Split_data/Validation/Group_7'

# %%
os.listdir(training_data_path)
# Out:
# ['idli', 'fried_rice', 'ice_cream']

# %%
os.listdir(validation_data_path)
# Out:
# ['idli', 'fried_rice', 'ice_cream']

# %%
os.listdir(training_data_path+'/fried_rice')
# Out:
# ['048.jpg',
#  '002.jpg',
#  'images (12).jpg',
#  '317.jpg',
#  '318.jpg',
#  '322.jpg',
#  '014.jpg',
#  'download (4).jpg',
#  '131.jpg',
#  '209.jpg',
#  '076.jpg',
#  '165.jpg',
#  '233.jpg',
#  '146.jpg',
#  '199.jpg',
#  '298.jpg',
#  '270.jpg',
#  '017.jpg',
#  '008.jpg',
#  '154.jpg',
#  '068.jpg',
#  '127.jpg',
#  '101.jpg',
#  '077.jpg',
#  '263.jpg',
#  '116.jpg',
#  '044.jpg',
#  '332.jpg',
#  '218.jpg',
#  '045.jpg',
#  '227.jpg',
#  '150.jpg',
#  '170.jpg',
#  '201.jpg',
#  '159.jpg',
#  '179.jpg',
#  '326.jpg',
#  '247.jpg',
#  '287.jpg',
#  '342.jpg',
#  '169.jpg',
#  '137.jpg',
#  '024.jpeg',
#  '308.jpg',
#  '339.jpg',
#  '171.jpg',
#  '105.jpg',
#  '079.jpg',
#  '059.jpg',
#  '103.jpg',
#  '026.jpg',
#  '109.jpg',
#  '107.jpg',
#  '335.jpg',
#  '087.jpg',
#  '302.jpg',
#  '283.jpg',
#  '099.jpg',
#  'images (7).jpg',
#  'download (3).jpg',
#  '093.jpg',
#  '181.jpg',
#  '316.jpg',
#  '220.jpg',
#  '228.jpg',
#  '003.jpg',
#  '280.jpg',
#  '053.jpg',
#  '143.jpg',
#  '178.jpg',
#  '089.jpg',
#  '203.jpg',
#  '246.jpg',
#  '333.jpg',
#  '152.jpg',
#  '144.jpg',
#  'download (11).jpg',
#  '230.jpg',
#  '305.jpg',
#  '102.jpg',
#  'images (2).jpg',
#  '040.jpg',
#  '262.jpg',
#  '196.jpg',
#  '035.jpg',
#  '135.jpg',
#  'images (11).jpg',
#  '037.jpg',
#  '315.jpg',
#  '130.jpg',
#  '095.jpg',
#  '124.jpg',
#  'download (6).jpg',
#  '029.jpg',
#  '108.jpg',
#  '088.jpg',
#  '064.jpg',
#  '226.jpg',
#  '292.jpg',
#  '222.jpg',
#  '096.jpg',
#  '176.jpg',
#  '065.jpg',
#  '235.jpg',
#  '343.jpg',
#  '338.jpg',
#  '031.jpg',
#  '081.jpg',
#  'images (4).jpg',
#  '320.jpg',
#  '348.jpg',
#  '057.jpg',
#  '202.jpg',
#  '100.jpg',
#  '189.jpg',
#  '291.jpg',
#  '132.jpg',
#  '310.jpg',
#  '225.jpg',
#  '257.jpg']

# %%
os.listdir(training_data_path+'/idli')
# Out:
# ['208.jpg',
#  '010.jpg',
#  '054.jpg',
#  '048.jpg',
#  '075.jpg',
#  'images (12).jpg',
#  'images (3).jpg',
#  '260.jpg',
#  'download (5).jpg',
#  '131.jpg',
#  '209.jpg',
#  '284.jpg',
#  '153.jpg',
#  'download.jpg',
#  '265.jpg',
#  '276.jpg',
#  '122.jpg',
#  '042.jpg',
#  '300.jpg',
#  '270.jpg',
#  '017.jpg',
#  '197.jpg',
#  '114.jpg',
#  '154.jpg',
#  '068.jpg',
#  '049.jpg',
#  '101.jpg',
#  '185.jpg',
#  '077.jpg',
#  '263.jpg',
#  '272.jpg',
#  '111.jpg',
#  '268.jpg',
#  '085.jpg',
#  '015.jpg',
#  '218.jpg',
#  '069.jpg',
#  '045.jpg',
#  '286.jpg',
#  '182.jpg',
#  '046.jpg',
#  '170.jpg',
#  '129.jpg',
#  '012.jpg',
#  '159.jpg',
#  '282.jpg',
#  'images (1).jpg',
#  '224.jpg',
#  'images (17).jpg',
#  '169.jpg',
#  '079.jpg',
#  '011.JPG',
#  '026.jpg',
#  '275.jpg',
#  '019.JPG',
#  '212.jpg',
#  '061.jpg',
#  '006.jpg',
#  '261.jpg',
#  '302.jpg',
#  '070.jpg',
#  '058.jpg',
#  'images (7).jpg',
#  '164.jpg',
#  '128.jpg',
#  '220.jpg',
#  '118.jpg',
#  '003.jpg',
#  '236.jpg',
#  '180.jpg',
#  '117.jpg',
#  '052.jpg',
#  'images (18).jpg',
#  'images (6).jpg',
#  '089.jpg',
#  '297.jpg',
#  '216.jpg',
#  '072.jpg',
#  '230.jpg',
#  '305.jpg',
#  '250.jpg',
#  '102.jpg',
#  '140.jpg',
#  '172.jpg',
#  '022.jpg',
#  '009.jpg',
#  '196.jpg',
#  '078.jpg',
#  'images (15).jpg',
#  '167.jpg',
#  '020.jpg',
#  'images (8).jpg',
#  '191.jpg',
#  '184.jpg',
#  '124.jpg',
#  '238.jpg',
#  '092.jpg',
#  '307.jpg',
#  '088.jpg',
#  '064.jpg',
#  '104.jpg',
#  '004.jpg',
#  '113.jpg',
#  '222.jpg',
#  '177.jpg',
#  '158.jpg',
#  '096.jpg',
#  '235.jpg',
#  '206.jpg',
#  '243.jpg',
#  '259.jpg',
#  '027.jpg',
#  '033.jpg',
#  'images (4).jpg',
#  '244.jpg',
#  '057.jpg',
#  '175.jpg',
#  '132.jpg',
#  '126.jpg',
#  '277.jpg']

# %%
plt.figure(figsize=(5,3))
plt.title('ice_cream')
Baked_potato = plt.imread(training_data_path + '/ice_cream/1052863.jpg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('idli')
Donut = plt.imread(training_data_path + '/idli/017.jpg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
group7_path = os.path.join(training_data_path)
labels = sorted([name for name in os.listdir(group7_path)
                 if os.path.isdir(os.path.join(group7_path, name))])
print("Group_7 Classes:", labels)
# Out:
# Group_7 Classes: ['fried_rice', 'ice_cream', 'idli']

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 20)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3

model = Sequential([
    Conv2D(32, (3,3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(256,256,3)),
                     BatchNormalization(),
                     MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
                      Dropout(0.3),
    Dense(num_classes, activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │    16,777,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,871,875 (64.36 MB)
#  Trainable params: 16,871,427 (64.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 112s 6s/step - accuracy: 0.5927 - loss: 2.4483 - val_accuracy: 0.3333 - val_loss: 7.1982
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.8003 - loss: 1.1155 - val_accuracy: 0.3417 - val_loss: 4.4423
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 120s 7s/step - accuracy: 0.8206 - loss: 0.8947 - val_accuracy: 0.3917 - val_loss: 4.2852
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.8368 - loss: 0.4311 - val_accuracy: 0.5083 - val_loss: 3.5466
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.8838 - loss: 0.3420 - val_accuracy: 0.6000 - val_loss: 2.3704
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 109s 6s/step - accuracy: 0.8684 - loss: 0.3367 - val_accuracy: 0.6917 - val_loss: 2.0058
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.8794 - loss: 0.2559 - val_accuracy: 0.6917 - val_loss: 1.9283
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9228 - loss: 0.1888 - val_accuracy: 0.7083 - val_loss: 1.5591
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 141s 6s/step - accuracy: 0.9029 - loss: 0.2735 - val_accuracy: 0.6917 - val_loss: 1.8511
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9525 - loss: 0.1603 - val_accuracy: 0.6667 - val_loss: 2.2325
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9362 - loss: 0.1559 - val_accuracy: 0.6167 - val_loss: 3.0943
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9332 - loss: 0.1766 - val_accuracy: 0.6083 - val_loss: 3.1835
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9590 - loss: 0.1339 - val_accuracy: 0.5500 - val_loss: 3.6204
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9312 - loss: 0.1676 - val_accuracy: 0.6000 - val_loss: 3.2583
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 105s 6s/step - accuracy: 0.9628 - loss: 0.0923 - val_accuracy: 0.6167 - val_loss: 3.0018
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9609 - loss: 0.1330 - val_accuracy: 0.6333 - val_loss: 3.0555
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9588 - loss: 0.1008 - val_accuracy: 0.5583 - val_loss: 3.2930
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9613 - loss: 0.0964 - val_accuracy: 0.5917 - val_loss: 2.1072
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9642 - loss: 0.0955 - val_accuracy: 0.6083 - val_loss: 2.4651
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9446 - loss: 0.1199 - val_accuracy: 0.6333 - val_loss: 2.0233
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 142s 6s/step - accuracy: 0.9644 - loss: 0.0964 - val_accuracy: 0.6833 - val_loss: 1.6292
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9697 - loss: 0.1539 - val_accuracy: 0.7250 - val_loss: 1.1917
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9659 - loss: 0.1096 - val_accuracy: 0.7333 - val_loss: 1.3392
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9677 - loss: 0.1201 - val_accuracy: 0.7333 - val_loss: 1.3962
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9490 - loss: 0.1351 - val_accuracy: 0.8083 - val_loss: 0.8683
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9556 - loss: 0.1189 - val_accuracy: 0.8000 - val_loss: 0.9811
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 142s 6s/step - accuracy: 0.9792 - loss: 0.0607 - val_accuracy: 0.7833 - val_loss: 0.9748
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9501 - loss: 0.1170 - val_accuracy: 0.8000 - val_loss: 0.8750
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9564 - loss: 0.0845 - val_accuracy: 0.8500 - val_loss: 0.6634
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 106s 6s/step - accuracy: 0.9508 - loss: 0.1256 - val_accuracy: 0.8417 - val_loss: 0.6668
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 106s 6s/step - accuracy: 0.9773 - loss: 0.0818 - val_accuracy: 0.8667 - val_loss: 0.7787
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9736 - loss: 0.0577 - val_accuracy: 0.8500 - val_loss: 0.7225
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9529 - loss: 0.1350 - val_accuracy: 0.8750 - val_loss: 0.6277
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9653 - loss: 0.0769 - val_accuracy: 0.8333 - val_loss: 0.7571
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9736 - loss: 0.0374 - val_accuracy: 0.8500 - val_loss: 0.8376
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9630 - loss: 0.0752 - val_accuracy: 0.7917 - val_loss: 0.7854
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9716 - loss: 0.0676 - val_accuracy: 0.8167 - val_loss: 0.7640
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9848 - loss: 0.0379 - val_accuracy: 0.8250 - val_loss: 0.7827
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 106s 6s/step - accuracy: 0.9794 - loss: 0.0549 - val_accuracy: 0.8167 - val_loss: 0.9058
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 143s 6s/step - accuracy: 0.9897 - loss: 0.0394 - val_accuracy: 0.8250 - val_loss: 0.7619
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 109s 6s/step - accuracy: 0.9894 - loss: 0.0423 - val_accuracy: 0.8417 - val_loss: 0.6098
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9967 - loss: 0.0197 - val_accuracy: 0.8417 - val_loss: 0.7172
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 109s 6s/step - accuracy: 0.9924 - loss: 0.0157 - val_accuracy: 0.8167 - val_loss: 0.9868
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 109s 6s/step - accuracy: 0.9856 - loss: 0.0484 - val_accuracy: 0.8583 - val_loss: 0.7141
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9882 - loss: 0.0393 - val_accuracy: 0.8500 - val_loss: 0.8080
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 106s 6s/step - accuracy: 0.9884 - loss: 0.0641 - val_accuracy: 0.8500 - val_loss: 0.6529
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.9749 - loss: 0.0608 - val_accuracy: 0.8500 - val_loss: 0.7008
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9909 - loss: 0.0227 - val_accuracy: 0.8083 - val_loss: 0.8663
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.9674 - loss: 0.0768 - val_accuracy: 0.8250 - val_loss: 0.8900
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 105s 6s/step - accuracy: 0.9880 - loss: 0.0242 - val_accuracy: 0.8167 - val_loss: 0.7427

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['fried_rice', 'ice_cream', 'idli']

# %%
train_input_data.class_indices
# Out:
# {'fried_rice': 0, 'ice_cream': 1, 'idli': 2}

# %%
def fun(path):
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # Load and preprocess the image
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # Predict using the model
    pred = model.predict(input_image)

    # Mapping only for Group_1 (train_input_data created from Group_1 folder)
    mapping = train_input_data.class_indices  # Automatically has only 3 classes
    inv_map = {v: k for k, v in mapping.items()}

    # Get predicted class index and label
    predicted_index = np.argmax(pred)
    predicted_label = inv_map[predicted_index]

    # Print for debugging
    print("Group_1 class mapping:", mapping)
    print("Model raw output:", pred)
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}")

    # Display image with prediction
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Split_data/Train/Group_7/fried_rice/024.jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# Group_1 class mapping: {'fried_rice': 0, 'ice_cream': 1, 'idli': 2}
# Model raw output: [[9.9999630e-01 3.7468524e-06 1.1606015e-09]]
# Predicted class index: 0
# Predicted label: fried_rice

# %%
fun('/content/Split_data/Train/Group_7/fried_rice/024.jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Group_1 class mapping: {'fried_rice': 0, 'ice_cream': 1, 'idli': 2}
# Model raw output: [[9.9999630e-01 3.7468524e-06 1.1606015e-09]]
# Predicted class index: 0
# Predicted label: fried_rice

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_7'

# %%
labels =  ['fried_rice', 'ice_cream', 'idli']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 490ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#   fried_rice       0.88      0.93      0.90        40
#    ice_cream       0.84      0.93      0.88        40
#         idli       0.85      0.72      0.78        40
#
#     accuracy                           0.86       120
#    macro avg       0.86      0.86      0.86       120
# weighted avg       0.86      0.86      0.86       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.8583

# %%
model.save('/content/train_group7.h5')
print("Model saved successfully at /content/custom_food_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully at /content/custom_food_model.h5

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/train_group7.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
