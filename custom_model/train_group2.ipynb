# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/INTERNSHIP_VIHARA/PROJECT2/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_2'
validation_data_path = '/content/Split_data/Validation/Group_2'

# %%
os.listdir(training_data_path)
# Out:
# ['Fries', 'Sandwich', 'Hot Dog']

# %%
os.listdir(validation_data_path)
# Out:
# ['Fries', 'Sandwich', 'Hot Dog']

# %%
os.listdir(training_data_path+'/Sandwich')
# Out:
# ['Sandwich-Train (1112).jpeg',
#  'Sandwich-Train (612).jpeg',
#  'Sandwich-Train (771).jpeg',
#  'Sandwich-Train (1500).jpeg',
#  'Sandwich-Train (765).jpeg',
#  'Sandwich-Train (784).jpeg',
#  'Sandwich-Train (333).jpeg',
#  'Sandwich-Train (37).jpeg',
#  'Sandwich-Train (1280).jpeg',
#  'Sandwich-Train (110).jpeg',
#  'Sandwich-Train (587).jpeg',
#  'Sandwich-Train (212).jpeg',
#  'Sandwich-Train (648).jpeg',
#  'Sandwich-Train (567).jpeg',
#  'Sandwich-Train (1437).jpeg',
#  'Sandwich-Train (1141).jpeg',
#  'Sandwich-Train (987).jpeg',
#  'Sandwich-Train (1492).jpeg',
#  'Sandwich-Train (1364).jpeg',
#  'Sandwich-Train (634).jpeg',
#  'Sandwich-Train (1265).jpeg',
#  'Sandwich-Train (749).jpeg',
#  'Sandwich-Train (656).jpeg',
#  'Sandwich-Train (741).jpeg',
#  'Sandwich-Train (589).jpeg',
#  'Sandwich-Train (1338).jpeg',
#  'Sandwich-Train (818).jpeg',
#  'Sandwich-Train (544).jpeg',
#  'Sandwich-Train (1442).jpeg',
#  'Sandwich-Train (1314).jpeg',
#  'Sandwich-Train (911).jpeg',
#  'Sandwich-Train (917).jpeg',
#  'Sandwich-Train (305).jpeg',
#  'Sandwich-Train (144).jpeg',
#  'Sandwich-Train (1268).jpeg',
#  'Sandwich-Train (541).jpeg',
#  'Sandwich-Train (174).jpeg',
#  'Sandwich-Train (58).jpeg',
#  'Sandwich-Train (1308).jpeg',
#  'Sandwich-Train (1243).jpeg',
#  'Sandwich-Train (217).jpeg',
#  'Sandwich-Train (631).jpeg',
#  'Sandwich-Train (1397).jpeg',
#  'Sandwich-Train (127).jpeg',
#  'Sandwich-Train (701).jpeg',
#  'Sandwich-Train (1146).jpeg',
#  'Sandwich-Train (1111).jpeg',
#  'Sandwich-Train (1428).jpeg',
#  'Sandwich-Train (394).jpeg',
#  'Sandwich-Train (228).jpeg',
#  'Sandwich-Train (375).jpeg',
#  'Sandwich-Train (710).jpeg',
#  'Sandwich-Train (528).jpeg',
#  'Sandwich-Train (159).jpeg',
#  'Sandwich-Train (12).jpeg',
#  'Sandwich-Train (1426).jpeg',
#  'Sandwich-Train (402).jpeg',
#  'Sandwich-Train (1021).jpeg',
#  'Sandwich-Train (728).jpeg',
#  'Sandwich-Train (1354).jpeg',
#  'Sandwich-Train (164).jpeg',
#  'Sandwich-Train (1087).jpeg',
#  'Sandwich-Train (1139).jpeg',
#  'Sandwich-Train (200).jpeg',
#  'Sandwich-Train (1046).jpeg',
#  'Sandwich-Train (1104).jpeg',
#  'Sandwich-Train (249).jpeg',
#  'Sandwich-Train (1262).jpeg',
#  'Sandwich-Train (411).jpeg',
#  'Sandwich-Train (1030).jpeg',
#  'Sandwich-Train (399).jpeg',
#  'Sandwich-Train (1360).jpeg',
#  'Sandwich-Train (755).jpeg',
#  'Sandwich-Train (232).jpeg',
#  'Sandwich-Train (287).jpeg',
#  'Sandwich-Train (1150).jpeg',
#  'Sandwich-Train (1481).jpeg',
#  'Sandwich-Train (609).jpeg',
#  'Sandwich-Train (312).jpeg',
#  'Sandwich-Train (913).jpeg',
#  'Sandwich-Train (642).jpeg',
#  'Sandwich-Train (33).jpeg',
#  'Sandwich-Train (196).jpeg',
#  'Sandwich-Train (979).jpeg',
#  'Sandwich-Train (280).jpeg',
#  'Sandwich-Train (1008).jpeg',
#  'Sandwich-Train (1389).jpeg',
#  'Sandwich-Train (554).jpeg',
#  'Sandwich-Train (1037).jpeg',
#  'Sandwich-Train (313).jpeg',
#  'Sandwich-Train (1463).jpeg',
#  'Sandwich-Train (1260).jpeg',
#  'Sandwich-Train (417).jpeg',
#  'Sandwich-Train (1429).jpeg',
#  'Sandwich-Train (538).jpeg',
#  'Sandwich-Train (1013).jpeg',
#  'Sandwich-Train (1433).jpeg',
#  'Sandwich-Train (219).jpeg',
#  'Sandwich-Train (234).jpeg',
#  'Sandwich-Train (1125).jpeg',
#  'Sandwich-Train (569).jpeg',
#  'Sandwich-Train (673).jpeg',
#  'Sandwich-Train (1220).jpeg',
#  'Sandwich-Train (1461).jpeg',
#  'Sandwich-Train (323).jpeg',
#  'Sandwich-Train (1491).jpeg',
#  'Sandwich-Train (1436).jpeg',
#  'Sandwich-Train (854).jpeg',
#  'Sandwich-Train (561).jpeg',
#  'Sandwich-Train (152).jpeg',
#  'Sandwich-Train (370).jpeg',
#  'Sandwich-Train (530).jpeg',
#  'Sandwich-Train (148).jpeg',
#  'Sandwich-Train (147).jpeg',
#  'Sandwich-Train (273).jpeg',
#  'Sandwich-Train (496).jpeg',
#  'Sandwich-Train (709).jpeg',
#  'Sandwich-Train (1309).jpeg',
#  'Sandwich-Train (924).jpeg',
#  'Sandwich-Train (997).jpeg']

# %%
os.listdir(training_data_path+'/Fries')
# Out:
# ['Fries-Train (708).jpeg',
#  'Fries-Train (675).jpeg',
#  'Fries-Train (763).jpeg',
#  'Fries-Train (1).jpeg',
#  'Fries-Train (986).jpeg',
#  'Fries-Train (297).jpeg',
#  'Fries-Train (522).jpeg',
#  'Fries-Train (1319).jpeg',
#  'Fries-Train (174).jpeg',
#  'Fries-Train (710).jpeg',
#  'Fries-Train (182).jpeg',
#  'Fries-Train (1402).jpeg',
#  'Fries-Train (1490).jpeg',
#  'Fries-Train (1239).jpeg',
#  'Fries-Train (1321).jpeg',
#  'Fries-Train (1212).jpeg',
#  'Fries-Train (243).jpeg',
#  'Fries-Train (105).jpeg',
#  'Fries-Train (941).jpeg',
#  'Fries-Train (219).jpeg',
#  'Fries-Train (993).jpeg',
#  'Fries-Train (1107).jpeg',
#  'Fries-Train (428).jpeg',
#  'Fries-Train (1108).jpeg',
#  'Fries-Train (46).jpeg',
#  'Fries-Train (655).jpeg',
#  'Fries-Train (764).jpeg',
#  'Fries-Train (343).jpeg',
#  'Fries-Train (1175).jpeg',
#  'Fries-Train (1157).jpeg',
#  'Fries-Train (210).jpeg',
#  'Fries-Train (221).jpeg',
#  'Fries-Train (1375).jpeg',
#  'Fries-Train (487).jpeg',
#  'Fries-Train (66).jpeg',
#  'Fries-Train (940).jpeg',
#  'Fries-Train (14).jpeg',
#  'Fries-Train (1141).jpeg',
#  'Fries-Train (1255).jpeg',
#  'Fries-Train (921).jpeg',
#  'Fries-Train (44).jpeg',
#  'Fries-Train (396).jpeg',
#  'Fries-Train (1395).jpeg',
#  'Fries-Train (420).jpeg',
#  'Fries-Train (194).jpeg',
#  'Fries-Train (363).jpeg',
#  'Fries-Train (1298).jpeg',
#  'Fries-Train (540).jpeg',
#  'Fries-Train (1450).jpeg',
#  'Fries-Train (265).jpeg',
#  'Fries-Train (1411).jpeg',
#  'Fries-Train (1287).jpeg',
#  'Fries-Train (845).jpeg',
#  'Fries-Train (692).jpeg',
#  'Fries-Train (661).jpeg',
#  'Fries-Train (190).jpeg',
#  'Fries-Train (114).jpeg',
#  'Fries-Train (862).jpeg',
#  'Fries-Train (180).jpeg',
#  'Fries-Train (1329).jpeg',
#  'Fries-Train (1129).jpeg',
#  'Fries-Train (839).jpeg',
#  'Fries-Train (486).jpeg',
#  'Fries-Train (175).jpeg',
#  'Fries-Train (178).jpeg',
#  'Fries-Train (1051).jpeg',
#  'Fries-Train (694).jpeg',
#  'Fries-Train (283).jpeg',
#  'Fries-Train (1120).jpeg',
#  'Fries-Train (766).jpeg',
#  'Fries-Train (614).jpeg',
#  'Fries-Train (612).jpeg',
#  'Fries-Train (300).jpeg',
#  'Fries-Train (1039).jpeg',
#  'Fries-Train (121).jpeg',
#  'Fries-Train (68).jpeg',
#  'Fries-Train (21).jpeg',
#  'Fries-Train (1441).jpeg',
#  'Fries-Train (1235).jpeg',
#  'Fries-Train (953).jpeg',
#  'Fries-Train (702).jpeg',
#  'Fries-Train (1333).jpeg',
#  'Fries-Train (161).jpeg',
#  'Fries-Train (712).jpeg',
#  'Fries-Train (945).jpeg',
#  'Fries-Train (258).jpeg',
#  'Fries-Train (223).jpeg',
#  'Fries-Train (1248).jpeg',
#  'Fries-Train (170).jpeg',
#  'Fries-Train (1275).jpeg',
#  'Fries-Train (568).jpeg',
#  'Fries-Train (1471).jpeg',
#  'Fries-Train (218).jpeg',
#  'Fries-Train (173).jpeg',
#  'Fries-Train (335).jpeg',
#  'Fries-Train (271).jpeg',
#  'Fries-Train (1457).jpeg',
#  'Fries-Train (231).jpeg',
#  'Fries-Train (42).jpeg',
#  'Fries-Train (801).jpeg',
#  'Fries-Train (705).jpeg',
#  'Fries-Train (128).jpeg',
#  'Fries-Train (578).jpeg',
#  'Fries-Train (1109).jpeg',
#  'Fries-Train (214).jpeg',
#  'Fries-Train (833).jpeg',
#  'Fries-Train (1370).jpeg',
#  'Fries-Train (719).jpeg',
#  'Fries-Train (1476).jpeg',
#  'Fries-Train (435).jpeg',
#  'Fries-Train (269).jpeg',
#  'Fries-Train (227).jpeg',
#  'Fries-Train (499).jpeg',
#  'Fries-Train (978).jpeg',
#  'Fries-Train (800).jpeg',
#  'Fries-Train (681).jpeg',
#  'Fries-Train (1481).jpeg',
#  'Fries-Train (1091).jpeg',
#  'Fries-Train (883).jpeg',
#  'Fries-Train (893).jpeg']

# %%
plt.figure(figsize=(5,3))
plt.title('sandwitch')
Baked_potato = plt.imread(training_data_path + '/Sandwich/Sandwich-Train (1150).jpeg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('fries_image')
Donut = plt.imread(training_data_path + '/Fries/Fries-Train (1039).jpeg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
group2_path = os.path.join(training_data_path)
labels = sorted([name for name in os.listdir(group2_path)
                 if os.path.isdir(os.path.join(group2_path, name))])
print("Group_1 Classes:", labels)
# Out:
# Group_1 Classes: ['Fries', 'Hot Dog', 'Sandwich']

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 20)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3

model = Sequential([
    Conv2D(32, (3,3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(256,256,3)),
                     BatchNormalization(),
                     MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
                      Dropout(0.3),
    Dense(num_classes, activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_14 (Conv2D)              │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │    16,777,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,871,875 (64.36 MB)
#  Trainable params: 16,871,427 (64.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 514ms/step - accuracy: 0.4080 - loss: 3.4609 - val_accuracy: 0.3583 - val_loss: 1.0950
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 405ms/step - accuracy: 0.5019 - loss: 1.3192 - val_accuracy: 0.4083 - val_loss: 1.1208
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 421ms/step - accuracy: 0.5697 - loss: 0.9083 - val_accuracy: 0.3583 - val_loss: 1.1575
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 587ms/step - accuracy: 0.6777 - loss: 0.7590 - val_accuracy: 0.4333 - val_loss: 1.2315
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 376ms/step - accuracy: 0.6702 - loss: 0.6685 - val_accuracy: 0.4000 - val_loss: 1.4687
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 449ms/step - accuracy: 0.6760 - loss: 0.7402 - val_accuracy: 0.4333 - val_loss: 1.4881
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.7179 - loss: 0.6608 - val_accuracy: 0.4333 - val_loss: 1.6035
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step - accuracy: 0.7676 - loss: 0.5888 - val_accuracy: 0.4083 - val_loss: 1.8533
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 584ms/step - accuracy: 0.7390 - loss: 0.5931 - val_accuracy: 0.4000 - val_loss: 1.9345
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 376ms/step - accuracy: 0.8196 - loss: 0.4783 - val_accuracy: 0.4083 - val_loss: 1.9875
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 489ms/step - accuracy: 0.8382 - loss: 0.4278 - val_accuracy: 0.3417 - val_loss: 2.0719
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 406ms/step - accuracy: 0.8386 - loss: 0.4109 - val_accuracy: 0.3750 - val_loss: 1.7754
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 419ms/step - accuracy: 0.8255 - loss: 0.4499 - val_accuracy: 0.4667 - val_loss: 1.6827
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 462ms/step - accuracy: 0.8658 - loss: 0.3880 - val_accuracy: 0.4583 - val_loss: 1.6911
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.8498 - loss: 0.3901 - val_accuracy: 0.4583 - val_loss: 1.6653
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 458ms/step - accuracy: 0.8696 - loss: 0.3648 - val_accuracy: 0.4750 - val_loss: 1.7280
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.8850 - loss: 0.3158 - val_accuracy: 0.4750 - val_loss: 1.5042
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 453ms/step - accuracy: 0.8766 - loss: 0.3339 - val_accuracy: 0.5083 - val_loss: 1.5254
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.8567 - loss: 0.3262 - val_accuracy: 0.4750 - val_loss: 1.5198
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 455ms/step - accuracy: 0.8921 - loss: 0.3266 - val_accuracy: 0.5417 - val_loss: 1.3690
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 409ms/step - accuracy: 0.9267 - loss: 0.2289 - val_accuracy: 0.5417 - val_loss: 1.4487
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 405ms/step - accuracy: 0.8729 - loss: 0.3169 - val_accuracy: 0.5500 - val_loss: 1.2013
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 457ms/step - accuracy: 0.8993 - loss: 0.2704 - val_accuracy: 0.5833 - val_loss: 1.3355
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.9291 - loss: 0.2350 - val_accuracy: 0.5417 - val_loss: 1.4568
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 448ms/step - accuracy: 0.9389 - loss: 0.2063 - val_accuracy: 0.5167 - val_loss: 1.4127
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.9469 - loss: 0.1691 - val_accuracy: 0.5667 - val_loss: 1.3295
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 448ms/step - accuracy: 0.9397 - loss: 0.2097 - val_accuracy: 0.6167 - val_loss: 1.3393
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.9671 - loss: 0.1460 - val_accuracy: 0.5750 - val_loss: 1.2350
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 456ms/step - accuracy: 0.9424 - loss: 0.1595 - val_accuracy: 0.5917 - val_loss: 1.2545
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 428ms/step - accuracy: 0.9561 - loss: 0.1613 - val_accuracy: 0.5333 - val_loss: 1.4279
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 392ms/step - accuracy: 0.9349 - loss: 0.1714 - val_accuracy: 0.5667 - val_loss: 1.3865
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 459ms/step - accuracy: 0.9404 - loss: 0.1695 - val_accuracy: 0.6083 - val_loss: 1.2173
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.9519 - loss: 0.1549 - val_accuracy: 0.6167 - val_loss: 1.3463
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 450ms/step - accuracy: 0.9642 - loss: 0.1289 - val_accuracy: 0.5583 - val_loss: 1.3764
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.9543 - loss: 0.1300 - val_accuracy: 0.5833 - val_loss: 1.3715
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 455ms/step - accuracy: 0.9322 - loss: 0.1472 - val_accuracy: 0.5750 - val_loss: 1.4174
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.9721 - loss: 0.1227 - val_accuracy: 0.5833 - val_loss: 1.3183
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 441ms/step - accuracy: 0.9311 - loss: 0.1517 - val_accuracy: 0.5500 - val_loss: 1.4533
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 443ms/step - accuracy: 0.9614 - loss: 0.1157 - val_accuracy: 0.6083 - val_loss: 1.3122
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 401ms/step - accuracy: 0.9587 - loss: 0.1303 - val_accuracy: 0.6500 - val_loss: 1.2641
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 473ms/step - accuracy: 0.9746 - loss: 0.0852 - val_accuracy: 0.6333 - val_loss: 1.1653
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 380ms/step - accuracy: 0.9685 - loss: 0.0967 - val_accuracy: 0.6250 - val_loss: 1.1158
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 467ms/step - accuracy: 0.9226 - loss: 0.2176 - val_accuracy: 0.6500 - val_loss: 1.2683
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.9569 - loss: 0.1329 - val_accuracy: 0.5833 - val_loss: 1.2353
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 477ms/step - accuracy: 0.9447 - loss: 0.1348 - val_accuracy: 0.5833 - val_loss: 1.3628
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 446ms/step - accuracy: 0.9653 - loss: 0.1215 - val_accuracy: 0.6333 - val_loss: 1.2194
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.9605 - loss: 0.0984 - val_accuracy: 0.5750 - val_loss: 1.2932
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 479ms/step - accuracy: 0.9659 - loss: 0.0897 - val_accuracy: 0.6167 - val_loss: 1.3529
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.9707 - loss: 0.0942 - val_accuracy: 0.5750 - val_loss: 1.4622
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 446ms/step - accuracy: 0.9539 - loss: 0.0979 - val_accuracy: 0.6417 - val_loss: 1.3442

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['Fries', 'Hot Dog', 'Sandwich']

# %%
train_input_data.class_indices
# Out:
# {'Fries': 0, 'Hot Dog': 1, 'Sandwich': 2}

# %%
def fun(path):
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # Load and preprocess the image
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # Predict using the model
    pred = model.predict(input_image)

    # Mapping only for Group_1 (train_input_data created from Group_1 folder)
    mapping = train_input_data.class_indices  # Automatically has only 3 classes
    inv_map = {v: k for k, v in mapping.items()}

    # Get predicted class index and label
    predicted_index = np.argmax(pred)
    predicted_label = inv_map[predicted_index]

    # Print for debugging
    print("Group_1 class mapping:", mapping)
    print("Model raw output:", pred)
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}")

    # Display image with prediction
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Split_data/Train/Group_2/Fries/Fries-Train (1129).jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Group_1 class mapping: {'Fries': 0, 'Hot Dog': 1, 'Sandwich': 2}
# Model raw output: [[9.9999881e-01 2.7141561e-14 1.1986086e-06]]
# Predicted class index: 0
# Predicted label: Fries

# %%
fun('/content/Split_data/Train/Group_2/Hot Dog/Hot Dog - Train (1130).jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Group_1 class mapping: {'Fries': 0, 'Hot Dog': 1, 'Sandwich': 2}
# Model raw output: [[4.8354495e-06 9.9991488e-01 8.0176636e-05]]
# Predicted class index: 1
# Predicted label: Hot Dog

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_1'

# %%
labels = ['Baked Potato', 'Crispy Chicken', 'Donut']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#   Baked Potato       0.22      0.17      0.19        40
# Crispy Chicken       0.23      0.25      0.24        40
#          Donut       0.29      0.33      0.31        40
#
#       accuracy                           0.25       120
#      macro avg       0.25      0.25      0.25       120
#   weighted avg       0.25      0.25      0.25       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.2500

# %%
model.save('/content/train_group2.h5')
print("Model saved successfully at /content/custom_food_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully at /content/custom_food_model.h5

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/train_group2.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
