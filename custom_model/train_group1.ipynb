# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/INTERNSHIP_VIHARA/PROJECT2/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_1'
validation_data_path = '/content/Split_data/Validation/Group_1'

# %%
os.listdir(training_data_path)
# Out:
# ['Crispy Chicken', 'Baked Potato', 'Donut']

# %%
os.listdir(validation_data_path)
# Out:
# ['Crispy Chicken', 'Baked Potato', 'Donut']

# %%
os.listdir(training_data_path+'/Crispy Chicken')
# Out:
# ['Crispy Chicken-Train (630).jpeg',
#  'Crispy Chicken-Train (280).jpeg',
#  'Crispy Chicken-Train (1131).jpeg',
#  'Crispy Chicken-Train (847).jpeg',
#  'Crispy Chicken-Train (1264).jpeg',
#  'Crispy Chicken-Train (671).jpeg',
#  'Crispy Chicken-Train (81).jpeg',
#  'Crispy Chicken-Train (148).jpeg',
#  'Crispy Chicken-Train (662).jpeg',
#  'Crispy Chicken-Train (878).jpeg',
#  'Crispy Chicken-Train (694).jpeg',
#  'Crispy Chicken-Train (473).jpeg',
#  'Crispy Chicken-Train (834).jpeg',
#  'Crispy Chicken-Train (1128).jpeg',
#  'Crispy Chicken-Train (905).jpeg',
#  'Crispy Chicken-Train (1467).jpeg',
#  'Crispy Chicken-Train (339).jpeg',
#  'Crispy Chicken-Train (1235).jpeg',
#  'Crispy Chicken-Train (424).jpeg',
#  'Crispy Chicken-Train (272).jpeg',
#  'Crispy Chicken-Train (1002).jpeg',
#  'Crispy Chicken-Train (1499).jpeg',
#  'Crispy Chicken-Train (850).jpeg',
#  'Crispy Chicken-Train (519).jpeg',
#  'Crispy Chicken-Train (5).jpeg',
#  'Crispy Chicken-Train (32).jpeg',
#  'Crispy Chicken-Train (1138).jpeg',
#  'Crispy Chicken-Train (1309).jpeg',
#  'Crispy Chicken-Train (394).jpeg',
#  'Crispy Chicken-Train (803).jpeg',
#  'Crispy Chicken-Train (887).jpeg',
#  'Crispy Chicken-Train (1166).jpeg',
#  'Crispy Chicken-Train (1071).jpeg',
#  'Crispy Chicken-Train (1059).jpeg',
#  'Crispy Chicken-Train (555).jpeg',
#  'Crispy Chicken-Train (1095).jpeg',
#  'Crispy Chicken-Train (1068).jpeg',
#  'Crispy Chicken-Train (124).jpeg',
#  'Crispy Chicken-Train (802).jpeg',
#  'Crispy Chicken-Train (1100).jpeg',
#  'Crispy Chicken-Train (952).jpeg',
#  'Crispy Chicken-Train (1299).jpeg',
#  'Crispy Chicken-Train (744).jpeg',
#  'Crispy Chicken-Train (1075).jpeg',
#  'Crispy Chicken-Train (70).jpeg',
#  'Crispy Chicken-Train (666).jpeg',
#  'Crispy Chicken-Train (911).jpeg',
#  'Crispy Chicken-Train (503).jpeg',
#  'Crispy Chicken-Train (794).jpeg',
#  'Crispy Chicken-Train (1323).jpeg',
#  'Crispy Chicken-Train (48).jpeg',
#  'Crispy Chicken-Train (853).jpeg',
#  'Crispy Chicken-Train (1053).jpeg',
#  'Crispy Chicken-Train (1337).jpeg',
#  'Crispy Chicken-Train (1018).jpeg',
#  'Crispy Chicken-Train (669).jpeg',
#  'Crispy Chicken-Train (53).jpeg',
#  'Crispy Chicken-Train (392).jpeg',
#  'Crispy Chicken-Train (1062).jpeg',
#  'Crispy Chicken-Train (299).jpeg',
#  'Crispy Chicken-Train (828).jpeg',
#  'Crispy Chicken-Train (734).jpeg',
#  'Crispy Chicken-Train (1421).jpeg',
#  'Crispy Chicken-Train (525).jpeg',
#  'Crispy Chicken-Train (292).jpeg',
#  'Crispy Chicken-Train (772).jpeg',
#  'Crispy Chicken-Train (470).jpeg',
#  'Crispy Chicken-Train (211).jpeg',
#  'Crispy Chicken-Train (386).jpeg',
#  'Crispy Chicken-Train (319).jpeg',
#  'Crispy Chicken-Train (1313).jpeg',
#  'Crispy Chicken-Train (695).jpeg',
#  'Crispy Chicken-Train (1332).jpeg',
#  'Crispy Chicken-Train (38).jpeg',
#  'Crispy Chicken-Train (982).jpeg',
#  'Crispy Chicken-Train (930).jpeg',
#  'Crispy Chicken-Train (894).jpeg',
#  'Crispy Chicken-Train (1480).jpeg',
#  'Crispy Chicken-Train (650).jpeg',
#  'Crispy Chicken-Train (422).jpeg',
#  'Crispy Chicken-Train (1054).jpeg',
#  'Crispy Chicken-Train (6).jpeg',
#  'Crispy Chicken-Train (291).jpeg',
#  'Crispy Chicken-Train (1217).jpeg',
#  'Crispy Chicken-Train (140).jpeg',
#  'Crispy Chicken-Train (131).jpeg',
#  'Crispy Chicken-Train (383).jpeg',
#  'Crispy Chicken-Train (218).jpeg',
#  'Crispy Chicken-Train (1282).jpeg',
#  'Crispy Chicken-Train (1197).jpeg',
#  'Crispy Chicken-Train (1447).jpeg',
#  'Crispy Chicken-Train (399).jpeg',
#  'Crispy Chicken-Train (113).jpeg',
#  'Crispy Chicken-Train (1285).jpeg',
#  'Crispy Chicken-Train (1220).jpeg',
#  'Crispy Chicken-Train (158).jpeg',
#  'Crispy Chicken-Train (1257).jpeg',
#  'Crispy Chicken-Train (551).jpeg',
#  'Crispy Chicken-Train (1460).jpeg',
#  'Crispy Chicken-Train (821).jpeg',
#  'Crispy Chicken-Train (843).jpeg',
#  'Crispy Chicken-Train (294).jpeg',
#  'Crispy Chicken-Train (1298).jpeg',
#  'Crispy Chicken-Train (430).jpeg',
#  'Crispy Chicken-Train (543).jpeg',
#  'Crispy Chicken-Train (927).jpeg',
#  'Crispy Chicken-Train (258).jpeg',
#  'Crispy Chicken-Train (172).jpeg',
#  'Crispy Chicken-Train (892).jpeg',
#  'Crispy Chicken-Train (1124).jpeg',
#  'Crispy Chicken-Train (328).jpeg',
#  'Crispy Chicken-Train (1451).jpeg',
#  'Crispy Chicken-Train (250).jpeg',
#  'Crispy Chicken-Train (942).jpeg',
#  'Crispy Chicken-Train (653).jpeg',
#  'Crispy Chicken-Train (214).jpeg',
#  'Crispy Chicken-Train (495).jpeg',
#  'Crispy Chicken-Train (1388).jpeg',
#  'Crispy Chicken-Train (527).jpeg',
#  'Crispy Chicken-Train (279).jpeg']

# %%
os.listdir(training_data_path+'/Baked Potato')
# Out:
# ['Baked Potato-Train (672).jpeg',
#  'Baked Potato-Train (1256).jpeg',
#  'Baked Potato-Train (1403).jpeg',
#  'Baked Potato-Train (254).jpeg',
#  'Baked Potato-Train (1422).jpeg',
#  'Baked Potato-Train (1280).jpeg',
#  'Baked Potato-Train (508).jpeg',
#  'Baked Potato-Train (1010).jpeg',
#  'Baked Potato-Train (1288).jpeg',
#  'Baked Potato-Train (1387).jpeg',
#  'Baked Potato-Train (411).jpeg',
#  'Baked Potato-Train (625).jpeg',
#  'Baked Potato-Train (236).jpeg',
#  'Baked Potato-Train (24).jpeg',
#  'Baked Potato-Train (979).jpeg',
#  'Baked Potato-Train (834).jpeg',
#  'Baked Potato-Train (318).jpeg',
#  'Baked Potato-Train (1214).jpeg',
#  'Baked Potato-Train (553).jpeg',
#  'Baked Potato-Train (1070).jpeg',
#  'Baked Potato-Train (621).jpeg',
#  'Baked Potato-Train (858).jpeg',
#  'Baked Potato-Train (758).jpeg',
#  'Baked Potato-Train (1205).jpeg',
#  'Baked Potato-Train (615).jpeg',
#  'Baked Potato-Train (1056).jpeg',
#  'Baked Potato-Train (589).jpeg',
#  'Baked Potato-Train (1414).jpeg',
#  'Baked Potato-Train (1378).jpeg',
#  'Baked Potato-Train (1106).jpeg',
#  'Baked Potato-Train (419).jpeg',
#  'Baked Potato-Train (152).jpeg',
#  'Baked Potato-Train (883).jpeg',
#  'Baked Potato-Train (14).jpeg',
#  'Baked Potato-Train (729).jpeg',
#  'Baked Potato-Train (983).jpeg',
#  'Baked Potato-Train (1084).jpeg',
#  'Baked Potato-Train (566).jpeg',
#  'Baked Potato-Train (1160).jpeg',
#  'Baked Potato-Train (759).jpeg',
#  'Baked Potato-Train (872).jpeg',
#  'Baked Potato-Train (113).jpeg',
#  'Baked Potato-Train (1150).jpeg',
#  'Baked Potato-Train (1012).jpeg',
#  'Baked Potato-Train (1367).jpeg',
#  'Baked Potato-Train (1457).jpeg',
#  'Baked Potato-Train (406).jpeg',
#  'Baked Potato-Train (782).jpeg',
#  'Baked Potato-Train (724).jpeg',
#  'Baked Potato-Train (275).jpeg',
#  'Baked Potato-Train (1357).jpeg',
#  'Baked Potato-Train (982).jpeg',
#  'Baked Potato-Train (628).jpeg',
#  'Baked Potato-Train (102).jpeg',
#  'Baked Potato-Train (1162).jpeg',
#  'Baked Potato-Train (298).jpeg',
#  'Baked Potato-Train (1436).jpeg',
#  'Baked Potato-Train (343).jpeg',
#  'Baked Potato-Train (1355).jpeg',
#  'Baked Potato-Train (1318).jpeg',
#  'Baked Potato-Train (828).jpeg',
#  'Baked Potato-Train (242).jpeg',
#  'Baked Potato-Train (579).jpeg',
#  'Baked Potato-Train (649).jpeg',
#  'Baked Potato-Train (1475).jpeg',
#  'Baked Potato-Train (1447).jpeg',
#  'Baked Potato-Train (993).jpeg',
#  'Baked Potato-Train (293).jpeg',
#  'Baked Potato-Train (1260).jpeg',
#  'Baked Potato-Train (807).jpeg',
#  'Baked Potato-Train (520).jpeg',
#  'Baked Potato-Train (278).jpeg',
#  'Baked Potato-Train (297).jpeg',
#  'Baked Potato-Train (1274).jpeg',
#  'Baked Potato-Train (1264).jpeg',
#  'Baked Potato-Train (992).jpeg',
#  'Baked Potato-Train (555).jpeg',
#  'Baked Potato-Train (246).jpeg',
#  'Baked Potato-Train (563).jpeg',
#  'Baked Potato-Train (1127).jpeg',
#  'Baked Potato-Train (745).jpeg',
#  'Baked Potato-Train (1032).jpeg',
#  'Baked Potato-Train (1197).jpeg',
#  'Baked Potato-Train (340).jpeg',
#  'Baked Potato-Train (1373).jpeg',
#  'Baked Potato-Train (1406).jpeg',
#  'Baked Potato-Train (1382).jpeg',
#  'Baked Potato-Train (1065).jpeg',
#  'Baked Potato-Train (142).jpeg',
#  'Baked Potato-Train (680).jpeg',
#  'Baked Potato-Train (1175).jpeg',
#  'Baked Potato-Train (1141).jpeg',
#  'Baked Potato-Train (370).jpeg',
#  'Baked Potato-Train (32).jpeg',
#  'Baked Potato-Train (213).jpeg',
#  'Baked Potato-Train (1246).jpeg',
#  'Baked Potato-Train (1043).jpeg',
#  'Baked Potato-Train (483).jpeg',
#  'Baked Potato-Train (1109).jpeg',
#  'Baked Potato-Train (455).jpeg',
#  'Baked Potato-Train (528).jpeg',
#  'Baked Potato-Train (148).jpeg',
#  'Baked Potato-Train (641).jpeg',
#  'Baked Potato-Train (1163).jpeg',
#  'Baked Potato-Train (1200).jpeg',
#  'Baked Potato-Train (1195).jpeg',
#  'Baked Potato-Train (788).jpeg',
#  'Baked Potato-Train (919).jpeg',
#  'Baked Potato-Train (547).jpeg',
#  'Baked Potato-Train (408).jpeg',
#  'Baked Potato-Train (1186).jpeg',
#  'Baked Potato-Train (229).jpeg',
#  'Baked Potato-Train (733).jpeg',
#  'Baked Potato-Train (840).jpeg',
#  'Baked Potato-Train (1323).jpeg',
#  'Baked Potato-Train (816).jpeg',
#  'Baked Potato-Train (556).jpeg',
#  'Baked Potato-Train (1226).jpeg',
#  'Baked Potato-Train (651).jpeg',
#  'Baked Potato-Train (338).jpeg']

# %%
plt.figure(figsize=(5,3))
plt.title('Baked potato')
Baked_potato = plt.imread(training_data_path + '/Baked Potato/Baked Potato-Train (1043).jpeg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('Donut_image')
Donut = plt.imread(training_data_path + '/Donut/Donut (1051).jpeg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
group1_path = os.path.join(training_data_path)
labels = sorted([name for name in os.listdir(group1_path)
                 if os.path.isdir(os.path.join(group1_path, name))])
print("Group_1 Classes:", labels)
# Out:
# Group_1 Classes: ['Baked Potato', 'Crispy Chicken', 'Donut']

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 20)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3

model = Sequential([
    Conv2D(32, (3,3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(256,256,3)),
                     BatchNormalization(),
                     MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
                      Dropout(0.3),
    Dense(num_classes, activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_11 (Conv2D)              │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │    16,777,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,871,875 (64.36 MB)
#  Trainable params: 16,871,427 (64.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 529ms/step - accuracy: 0.6381 - loss: 1.2067 - val_accuracy: 0.4083 - val_loss: 1.3473
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.6913 - loss: 0.8925 - val_accuracy: 0.4417 - val_loss: 1.7140
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 452ms/step - accuracy: 0.6826 - loss: 0.7487 - val_accuracy: 0.4750 - val_loss: 2.4659
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.7755 - loss: 0.5648 - val_accuracy: 0.5333 - val_loss: 2.6649
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 457ms/step - accuracy: 0.8243 - loss: 0.4403 - val_accuracy: 0.5667 - val_loss: 2.6265
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 407ms/step - accuracy: 0.8283 - loss: 0.4328 - val_accuracy: 0.4750 - val_loss: 3.1659
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 377ms/step - accuracy: 0.7871 - loss: 0.6227 - val_accuracy: 0.5750 - val_loss: 3.1759
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 450ms/step - accuracy: 0.8018 - loss: 0.4967 - val_accuracy: 0.5333 - val_loss: 3.5319
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.8372 - loss: 0.4118 - val_accuracy: 0.4750 - val_loss: 3.4368
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 448ms/step - accuracy: 0.8933 - loss: 0.3334 - val_accuracy: 0.4917 - val_loss: 3.0276
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 424ms/step - accuracy: 0.9034 - loss: 0.2301 - val_accuracy: 0.5167 - val_loss: 2.5782
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.8826 - loss: 0.2746 - val_accuracy: 0.5917 - val_loss: 2.3061
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 524ms/step - accuracy: 0.9113 - loss: 0.2382 - val_accuracy: 0.5250 - val_loss: 2.0899
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.8729 - loss: 0.3270 - val_accuracy: 0.5833 - val_loss: 2.0128
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 448ms/step - accuracy: 0.8929 - loss: 0.2314 - val_accuracy: 0.5667 - val_loss: 1.9351
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.9155 - loss: 0.2383 - val_accuracy: 0.6167 - val_loss: 1.9583
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 449ms/step - accuracy: 0.9096 - loss: 0.2938 - val_accuracy: 0.6500 - val_loss: 1.9031
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 584ms/step - accuracy: 0.8919 - loss: 0.3312 - val_accuracy: 0.6000 - val_loss: 1.7365
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.9286 - loss: 0.2543 - val_accuracy: 0.6250 - val_loss: 1.5786
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 454ms/step - accuracy: 0.9165 - loss: 0.1942 - val_accuracy: 0.6917 - val_loss: 1.4704
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.8964 - loss: 0.2333 - val_accuracy: 0.6833 - val_loss: 1.5820
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 439ms/step - accuracy: 0.9302 - loss: 0.1847 - val_accuracy: 0.7000 - val_loss: 1.5839
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 444ms/step - accuracy: 0.9554 - loss: 0.1660 - val_accuracy: 0.7417 - val_loss: 1.5552
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.9351 - loss: 0.1876 - val_accuracy: 0.6750 - val_loss: 1.6444
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 464ms/step - accuracy: 0.9299 - loss: 0.1787 - val_accuracy: 0.7167 - val_loss: 1.5111
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.9465 - loss: 0.1371 - val_accuracy: 0.7083 - val_loss: 1.6085
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 460ms/step - accuracy: 0.9507 - loss: 0.1606 - val_accuracy: 0.7250 - val_loss: 1.6513
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 379ms/step - accuracy: 0.9326 - loss: 0.1417 - val_accuracy: 0.7083 - val_loss: 1.7246
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 457ms/step - accuracy: 0.9550 - loss: 0.1091 - val_accuracy: 0.7167 - val_loss: 1.6941
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 424ms/step - accuracy: 0.9188 - loss: 0.1496 - val_accuracy: 0.7417 - val_loss: 1.6363
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 403ms/step - accuracy: 0.9106 - loss: 0.2186 - val_accuracy: 0.7250 - val_loss: 1.5416
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 459ms/step - accuracy: 0.8974 - loss: 0.3172 - val_accuracy: 0.7167 - val_loss: 1.8909
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.9592 - loss: 0.1134 - val_accuracy: 0.7417 - val_loss: 1.5256
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 455ms/step - accuracy: 0.9240 - loss: 0.1622 - val_accuracy: 0.7417 - val_loss: 1.7028
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 379ms/step - accuracy: 0.9684 - loss: 0.0946 - val_accuracy: 0.7083 - val_loss: 1.7123
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 476ms/step - accuracy: 0.9636 - loss: 0.1089 - val_accuracy: 0.7583 - val_loss: 1.7267
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 413ms/step - accuracy: 0.9682 - loss: 0.1291 - val_accuracy: 0.7000 - val_loss: 1.8336
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 448ms/step - accuracy: 0.9521 - loss: 0.1120 - val_accuracy: 0.7417 - val_loss: 1.6149
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 478ms/step - accuracy: 0.9474 - loss: 0.1281 - val_accuracy: 0.7250 - val_loss: 1.5679
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.9682 - loss: 0.0666 - val_accuracy: 0.7000 - val_loss: 1.7164
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 481ms/step - accuracy: 0.9518 - loss: 0.0852 - val_accuracy: 0.7000 - val_loss: 1.4740
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 395ms/step - accuracy: 0.9463 - loss: 0.1126 - val_accuracy: 0.7167 - val_loss: 1.3898
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 469ms/step - accuracy: 0.9586 - loss: 0.1261 - val_accuracy: 0.7250 - val_loss: 1.6422
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 455ms/step - accuracy: 0.9839 - loss: 0.0464 - val_accuracy: 0.7250 - val_loss: 1.6989
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 380ms/step - accuracy: 0.9932 - loss: 0.0456 - val_accuracy: 0.7083 - val_loss: 1.7758
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 457ms/step - accuracy: 0.9694 - loss: 0.0746 - val_accuracy: 0.7333 - val_loss: 1.7239
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.9531 - loss: 0.0925 - val_accuracy: 0.7333 - val_loss: 1.7479
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 460ms/step - accuracy: 0.9797 - loss: 0.0522 - val_accuracy: 0.7583 - val_loss: 1.6374
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step - accuracy: 0.9722 - loss: 0.0979 - val_accuracy: 0.7333 - val_loss: 1.7281
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.9547 - loss: 0.0890 - val_accuracy: 0.7417 - val_loss: 1.7905

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['Baked Potato', 'Crispy Chicken', 'Donut']

# %%
train_input_data.class_indices
# Out:
# {'Baked Potato': 0, 'Crispy Chicken': 1, 'Donut': 2}

# %%
def fun(path):
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # Load and preprocess the image
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # Predict using the model
    pred = model.predict(input_image)

    # Mapping only for Group_1 (train_input_data created from Group_1 folder)
    mapping = train_input_data.class_indices  # Automatically has only 3 classes
    inv_map = {v: k for k, v in mapping.items()}

    # Get predicted class index and label
    predicted_index = np.argmax(pred)
    predicted_label = inv_map[predicted_index]

    # Print for debugging
    print("Group_1 class mapping:", mapping)
    print("Model raw output:", pred)
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}")

    # Display image with prediction
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Baked Potato-Train (845).jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Group_1 class mapping: {'Baked Potato': 0, 'Crispy Chicken': 1, 'Donut': 2}
# Model raw output: [[9.9978256e-01 3.1986430e-05 1.8541807e-04]]
# Predicted class index: 0
# Predicted label: Baked Potato

# %%
fun('/content/Donut (415).jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Group_1 class mapping: {'Baked Potato': 0, 'Crispy Chicken': 1, 'Donut': 2}
# Model raw output: [[5.6913559e-04 1.2899804e-03 9.9814093e-01]]
# Predicted class index: 2
# Predicted label: Donut

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_1'

# %%
labels = ['Baked Potato', 'Crispy Chicken', 'Donut']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#   Baked Potato       0.68      0.70      0.69        40
# Crispy Chicken       0.71      0.72      0.72        40
#          Donut       0.79      0.75      0.77        40
#
#       accuracy                           0.72       120
#      macro avg       0.73      0.72      0.73       120
#   weighted avg       0.73      0.72      0.73       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.7250

# %%
model.save('/content/train_group1.h5')
print("Model saved successfully at /content/custom_food_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully at /content/custom_food_model.h5

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/train_group1.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
