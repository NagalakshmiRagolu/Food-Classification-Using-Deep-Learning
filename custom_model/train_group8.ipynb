# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/INTERNSHIP_VIHARA/PROJECT2/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_8'
validation_data_path = '/content/Split_data/Validation/Group_8'

# %%
os.listdir(training_data_path)
# Out:
# ['jalebi', 'kaathi_rolls', 'kadai_paneer']

# %%
os.listdir(validation_data_path)
# Out:
# ['jalebi', 'kaathi_rolls', 'kadai_paneer']

# %%
os.listdir(training_data_path+'/jalebi')
# Out:
# ['243.jpg',
#  '033.jpg',
#  '043.jpg',
#  '046.jpg',
#  '027.jpg',
#  '265.jpg',
#  '070.jpg',
#  '143.jpg',
#  '186.jpg',
#  '079.jpg',
#  '260.jpg',
#  '055.jpg',
#  '241.jpg',
#  '016.jpg',
#  '053.jpg',
#  '149.jpg',
#  '080.jpg',
#  '172.jpg',
#  '221.jpg',
#  '102.jpg',
#  'images (11).jpg',
#  'download (7).jpg',
#  '136.jpg',
#  '129.jpg',
#  '188.jpg',
#  '137.jpg',
#  '235.jpg',
#  '162.jpg',
#  'download (2).jpg',
#  '239.jpg',
#  '067.jpg',
#  '121.jpg',
#  '216.jpg',
#  '078.jpg',
#  '002.jpg',
#  '158.jpg',
#  '139.jpg',
#  '196.jpg',
#  '009.jpg',
#  '005.jpg',
#  'images (6).jpg',
#  '171.jpg',
#  '205.jpg',
#  'images.jpg',
#  '021.jpg',
#  '209.jpg',
#  '045.jpg',
#  '199.jpg',
#  '224.jpg',
#  '059.jpg',
#  '157.jpg',
#  '161.jpg',
#  '182.jpg',
#  '259.jpg',
#  '266.jpg',
#  '201.jpg',
#  '197.jpg',
#  'download (5).jpg',
#  '049.jpg',
#  '203.jpg',
#  '104.jpg',
#  '277.jpg',
#  '044.jpg',
#  '114.jpg',
#  '108.jpg',
#  '130.jpg',
#  'images (4).jpg',
#  '013.jpg',
#  'download (6).jpg',
#  '279.jpg',
#  '003.jpg',
#  '289.jpg',
#  '074.jpg',
#  '020.jpg',
#  '036.jpg',
#  '180.jpg',
#  '166.jpg',
#  '085.jpg',
#  '091.jpg',
#  '004.jpg',
#  '220.jpg',
#  '290.jpg',
#  '111.jpg',
#  '276.jpg',
#  '218.jpg',
#  '195.jpg',
#  '017.jpg',
#  '118.jpg',
#  '256.jpg',
#  '122.jpg',
#  '269.jpg',
#  'images (10).jpg',
#  '249.jpg',
#  '133.jpg',
#  '056.jpg',
#  '252.jpg',
#  'images (8).jpg',
#  '236.jpg',
#  '183.jpg',
#  '281.jpg',
#  '228.jpg',
#  '066.jpg',
#  '101.jpg',
#  '193.jpg',
#  '164.jpg',
#  '120.jpg',
#  '285.jpg',
#  '273.jpg',
#  '215.jpg',
#  '267.jpg',
#  '007.jpg',
#  '284.jpg',
#  '240.jpg',
#  '075.jpg',
#  '262.jpg',
#  '023.jpg',
#  '198.jpg',
#  '167.jpg',
#  '263.jpg',
#  '156.jpg']

# %%
os.listdir(training_data_path+'/kaathi_rolls')
# Out:
# ['152.jpg',
#  '243.jpg',
#  '088.jpg',
#  '033.jpg',
#  '083.jpg',
#  '046.jpg',
#  '175.jpg',
#  '234.jpg',
#  '073.jpg',
#  '143.jpg',
#  '186.jpg',
#  '055.jpg',
#  '039.jpg',
#  '241.jpg',
#  '048.jpg',
#  '255.jpg',
#  '147.jpg',
#  '016.jpg',
#  '149.jpg',
#  '069.jpg',
#  '172.jpg',
#  '112.jpg',
#  '278.jpg',
#  '227.jpg',
#  '136.jpg',
#  '138.jpg',
#  '026.jpg',
#  '226.jpg',
#  '188.jpg',
#  '176.jpg',
#  '035.jpg',
#  '038.jpg',
#  '137.jpg',
#  'download (2).jpg',
#  '067.jpg',
#  '185.jpg',
#  '222.jpg',
#  '211.jpg',
#  '288.jpg',
#  '009.jpg',
#  'images (6).jpg',
#  '283.jpg',
#  '171.jpg',
#  '076.jpg',
#  '291.jpg',
#  '179.jpg',
#  'images (17).jpg',
#  '244.jpg',
#  '199.jpg',
#  'images (2).jpg',
#  '207.jpg',
#  '157.jpg',
#  '163.jpg',
#  'images (7).jpg',
#  '077.jpg',
#  '037.jpg',
#  '168.jpg',
#  '257.jpg',
#  '140.jpg',
#  '187.jpg',
#  '259.jpg',
#  '266.jpg',
#  '057.jpg',
#  '197.jpg',
#  'images (15).jpg',
#  'download (5).jpg',
#  '015.jpg',
#  '189.jpg',
#  '072.jpg',
#  'images (9).jpg',
#  '277.jpg',
#  '030.jpg',
#  '050.jpg',
#  'images (4).jpg',
#  '062.jpg',
#  'download (6).jpg',
#  '165.jpg',
#  '025.jpg',
#  '190.jpg',
#  '213.jpg',
#  '018.jpg',
#  '003.jpg',
#  '202.jpg',
#  '051.jpg',
#  'download (1).jpg',
#  'images (1).jpg',
#  '095.jpg',
#  '166.jpg',
#  '098.jpg',
#  '250.jpg',
#  '184.jpg',
#  '237.jpg',
#  '092.jpg',
#  '113.jpg',
#  '040.jpg',
#  '091.jpg',
#  '125.jpg',
#  '276.jpg',
#  '032.jpg',
#  'images (12).jpg',
#  '082.jpg',
#  '122.jpg',
#  '097.jpg',
#  '269.jpg',
#  '052.jpg',
#  '293.jpg',
#  '131.jpg',
#  'images (8).jpg',
#  '236.jpg',
#  '183.jpg',
#  '066.jpg',
#  '286.jpg',
#  '193.jpg',
#  '240.jpg',
#  '071.jpg',
#  '075.jpg',
#  '262.jpg',
#  '264.jpg',
#  '198.jpg',
#  '105.jpg']

# %%
plt.figure(figsize=(5,3))
plt.title('kadai_paneer')
Baked_potato = plt.imread(training_data_path + '/kadai_paneer/004.jpg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('kaathi_rolls')
Donut = plt.imread(training_data_path + '/kaathi_rolls/035.jpg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
group8_path = os.path.join(training_data_path)
labels = sorted([name for name in os.listdir(group8_path)
                 if os.path.isdir(os.path.join(group8_path, name))])
print("Group_8 Classes:", labels)
# Out:
# Group_8 Classes: ['jalebi', 'kaathi_rolls', 'kadai_paneer']

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 20)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3

model = Sequential([
    Conv2D(32, (3,3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(256,256,3)),
                     BatchNormalization(),
                     MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', kernel_initializer='he_uniform', padding='same'),
                      BatchNormalization(),
                      MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
                      Dropout(0.3),
    Dense(num_classes, activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    16,777,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,871,875 (64.36 MB)
#  Trainable params: 16,871,427 (64.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 106s 6s/step - accuracy: 0.4849 - loss: 3.3004 - val_accuracy: 0.4000 - val_loss: 1.0737
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 100s 6s/step - accuracy: 0.7218 - loss: 0.9630 - val_accuracy: 0.5250 - val_loss: 1.0300
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 149s 6s/step - accuracy: 0.7300 - loss: 0.6182 - val_accuracy: 0.5000 - val_loss: 1.4642
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 103s 6s/step - accuracy: 0.8267 - loss: 0.4675 - val_accuracy: 0.5500 - val_loss: 2.0164
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 101s 6s/step - accuracy: 0.8238 - loss: 0.4340 - val_accuracy: 0.5667 - val_loss: 3.0197
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 143s 6s/step - accuracy: 0.7945 - loss: 0.4746 - val_accuracy: 0.5917 - val_loss: 3.3960
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 103s 6s/step - accuracy: 0.8065 - loss: 0.4262 - val_accuracy: 0.6083 - val_loss: 3.6197
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 103s 6s/step - accuracy: 0.8813 - loss: 0.3101 - val_accuracy: 0.6167 - val_loss: 3.9617
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 111s 6s/step - accuracy: 0.8788 - loss: 0.2987 - val_accuracy: 0.6250 - val_loss: 4.1606
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.8953 - loss: 0.2344 - val_accuracy: 0.6083 - val_loss: 3.9164
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.8936 - loss: 0.3033 - val_accuracy: 0.6500 - val_loss: 3.7783
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9028 - loss: 0.2333 - val_accuracy: 0.6000 - val_loss: 3.6666
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 101s 6s/step - accuracy: 0.9162 - loss: 0.2308 - val_accuracy: 0.6333 - val_loss: 2.7659
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 101s 6s/step - accuracy: 0.8894 - loss: 0.2785 - val_accuracy: 0.6583 - val_loss: 2.7772
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 117s 6s/step - accuracy: 0.9162 - loss: 0.2373 - val_accuracy: 0.6583 - val_loss: 2.5321
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9119 - loss: 0.1935 - val_accuracy: 0.6833 - val_loss: 2.3261
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9178 - loss: 0.1952 - val_accuracy: 0.6417 - val_loss: 1.9855
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9236 - loss: 0.1742 - val_accuracy: 0.6917 - val_loss: 2.0993
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9312 - loss: 0.2366 - val_accuracy: 0.6417 - val_loss: 1.7643
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9452 - loss: 0.1889 - val_accuracy: 0.6833 - val_loss: 1.8818
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 112s 6s/step - accuracy: 0.9363 - loss: 0.1554 - val_accuracy: 0.7250 - val_loss: 1.1932
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 103s 6s/step - accuracy: 0.9514 - loss: 0.1331 - val_accuracy: 0.6833 - val_loss: 1.4184
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9541 - loss: 0.1277 - val_accuracy: 0.7250 - val_loss: 1.0630
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9227 - loss: 0.2209 - val_accuracy: 0.7000 - val_loss: 1.3806
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9137 - loss: 0.1758 - val_accuracy: 0.7083 - val_loss: 1.5679
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9325 - loss: 0.1559 - val_accuracy: 0.7167 - val_loss: 1.3105
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 142s 6s/step - accuracy: 0.9732 - loss: 0.1021 - val_accuracy: 0.6833 - val_loss: 1.3677
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 142s 6s/step - accuracy: 0.9790 - loss: 0.0813 - val_accuracy: 0.7250 - val_loss: 1.2313
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 103s 6s/step - accuracy: 0.9782 - loss: 0.0665 - val_accuracy: 0.7750 - val_loss: 0.9324
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9355 - loss: 0.1762 - val_accuracy: 0.7417 - val_loss: 1.1544
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9507 - loss: 0.1494 - val_accuracy: 0.7250 - val_loss: 1.0361
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9658 - loss: 0.0762 - val_accuracy: 0.7917 - val_loss: 0.7160
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 103s 6s/step - accuracy: 0.9560 - loss: 0.1027 - val_accuracy: 0.7250 - val_loss: 0.9297
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9539 - loss: 0.0960 - val_accuracy: 0.7500 - val_loss: 1.3071
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 143s 6s/step - accuracy: 0.9523 - loss: 0.1406 - val_accuracy: 0.7250 - val_loss: 1.0096
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9754 - loss: 0.0842 - val_accuracy: 0.7417 - val_loss: 1.0054
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9595 - loss: 0.1412 - val_accuracy: 0.7417 - val_loss: 0.9116
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 143s 6s/step - accuracy: 0.9483 - loss: 0.0983 - val_accuracy: 0.7667 - val_loss: 1.1167
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9792 - loss: 0.0673 - val_accuracy: 0.7667 - val_loss: 0.9146
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 101s 6s/step - accuracy: 0.9699 - loss: 0.0613 - val_accuracy: 0.8167 - val_loss: 0.9585
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9648 - loss: 0.0643 - val_accuracy: 0.7667 - val_loss: 0.8887
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9746 - loss: 0.0827 - val_accuracy: 0.7750 - val_loss: 0.8296
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9865 - loss: 0.0547 - val_accuracy: 0.8083 - val_loss: 1.0221
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 103s 6s/step - accuracy: 0.9942 - loss: 0.0350 - val_accuracy: 0.7833 - val_loss: 1.0693
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9651 - loss: 0.0951 - val_accuracy: 0.7667 - val_loss: 1.2600
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9875 - loss: 0.0432 - val_accuracy: 0.8083 - val_loss: 1.0695
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 103s 6s/step - accuracy: 0.9908 - loss: 0.0444 - val_accuracy: 0.7917 - val_loss: 1.1947
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 102s 6s/step - accuracy: 0.9478 - loss: 0.1342 - val_accuracy: 0.7750 - val_loss: 0.9347
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9485 - loss: 0.0822 - val_accuracy: 0.7667 - val_loss: 1.4403
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 104s 6s/step - accuracy: 0.9660 - loss: 0.1237 - val_accuracy: 0.7583 - val_loss: 1.2539

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['jalebi', 'kaathi_rolls', 'kadai_paneer']

# %%
train_input_data.class_indices
# Out:
# {'jalebi': 0, 'kaathi_rolls': 1, 'kadai_paneer': 2}

# %%
def fun(path):
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # Load and preprocess the image
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # Predict using the model
    pred = model.predict(input_image)

    # Mapping only for Group_1 (train_input_data created from Group_1 folder)
    mapping = train_input_data.class_indices  # Automatically has only 3 classes
    inv_map = {v: k for k, v in mapping.items()}

    # Get predicted class index and label
    predicted_index = np.argmax(pred)
    predicted_label = inv_map[predicted_index]

    # Print for debugging
    print("Group_1 class mapping:", mapping)
    print("Model raw output:", pred)
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}")

    # Display image with prediction
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Split_data/Train/Group_8/kaathi_rolls/171.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# Group_1 class mapping: {'jalebi': 0, 'kaathi_rolls': 1, 'kadai_paneer': 2}
# Model raw output: [[1.0670843e-15 1.0000000e+00 4.6941834e-18]]
# Predicted class index: 1
# Predicted label: kaathi_rolls

# %%
fun('/content/Split_data/Train/Group_8/kadai_paneer/004.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Group_1 class mapping: {'jalebi': 0, 'kaathi_rolls': 1, 'kadai_paneer': 2}
# Model raw output: [[1.6565339e-04 3.3561592e-10 9.9983430e-01]]
# Predicted class index: 2
# Predicted label: kadai_paneer

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_8'

# %%
labels = ['jalebi', 'kaathi_rolls', 'kadai_paneer']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       jalebi       0.82      0.68      0.74        40
# kaathi_rolls       0.90      0.70      0.79        40
# kadai_paneer       0.61      0.85      0.71        40
#
#     accuracy                           0.74       120
#    macro avg       0.78      0.74      0.75       120
# weighted avg       0.78      0.74      0.75       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.7417

# %%
model.save('/content/train_group8.h5')
print("Model saved successfully at /content/custom_food_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully at /content/custom_food_model.h5

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/train_group8.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
