# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_4'
validation_data_path = '/content/Split_data/Validation/Group_4'

# %%
os.listdir(training_data_path)
# Out:
# ['chai', 'burger', 'butter_naan']

# %%
os.listdir(validation_data_path)
# Out:
# ['chai', 'burger', 'butter_naan']

# %%
os.listdir(training_data_path+'/burger')
# Out:
# ['216.jpg',
#  '266.jpg',
#  '063.jpg',
#  '061.jpg',
#  '236.jpg',
#  '036.jpg',
#  '192.jpg',
#  '144.jpg',
#  '007.jpg',
#  '162.jpg',
#  '174.jpg',
#  '003.jpg',
#  '303.jpg',
#  '193.jpg',
#  '298.jpg',
#  '065.jpg',
#  '250.jpg',
#  '152.jpg',
#  'images.jpg',
#  '163.jpg',
#  '078.jpg',
#  '008.jpg',
#  '178.jpg',
#  '307.jpg',
#  'images (4).jpg',
#  '088.jpg',
#  '200.jpg',
#  '053.jpg',
#  '220.jpg',
#  '205.jpg',
#  '048.jpg',
#  '034.jpg',
#  '248.jpg',
#  '306.jpg',
#  '184.jpg',
#  '077.jpg',
#  '006.jpg',
#  '221.jpg',
#  '244.jpg',
#  '251.jpg',
#  '180.jpg',
#  '056.jpg',
#  '264.jpg',
#  '091.jpg',
#  '009.jpg',
#  '172.jpg',
#  '233.jpg',
#  '149.jpg',
#  '256.jpg',
#  '073.jpg',
#  '190.jpg',
#  '027.jpg',
#  '188.jpg',
#  '023.jpg',
#  '103.jpg',
#  '161.jpg',
#  'images (7).jpg',
#  '041.jpg',
#  '196.jpg',
#  '074.jpg',
#  '101.jpg',
#  '286.jpg',
#  '164.jpg',
#  '247.jpg',
#  '295.jpg',
#  'images (11).jpg',
#  'images (22).jpg',
#  '252.jpg',
#  'download (4).jpg',
#  '259.jpg',
#  'images (5).jpg',
#  '068.jpg',
#  '194.jpg',
#  '113.jpg',
#  '043.jpg',
#  '249.jpg',
#  '011.jpg',
#  '183.jpg',
#  '076.jpg',
#  '255.jpg',
#  '237.jpg',
#  'images (16).jpg',
#  '058.jpg',
#  '060.jpg',
#  '232.jpg',
#  '050.jpg',
#  '002.jpg',
#  '114.jpg',
#  '150.jpg',
#  '001.jpg',
#  'images (8).jpg',
#  '119.jpg',
#  '181.jpg',
#  'images (21).jpg',
#  '158.jpg',
#  '241.jpg',
#  '035.jpg',
#  '283.jpg',
#  '037.jpg',
#  '066.jpg',
#  '217.jpg',
#  '272.jpg',
#  '218.jpg',
#  '285.jpg',
#  '031.jpg',
#  '109.jpg',
#  '186.jpg',
#  '165.jpg',
#  '282.jpg',
#  '097.jpg',
#  '228.jpg',
#  '024.jpg',
#  '294.jpg',
#  '201.jpg',
#  '039.jpg',
#  '017.jpg',
#  '199.jpg',
#  '135.jpg',
#  'images (6).jpg',
#  '213.jpg']

# %%
os.listdir(training_data_path+'/butter_naan')
# Out:
# ['216.jpg',
#  '240.jpg',
#  '015.jpg',
#  '175.jpg',
#  '096.jpg',
#  '061.jpg',
#  '236.jpg',
#  '105.jpg',
#  '281.jpg',
#  '316.jpg',
#  '087.jpg',
#  '090.jpg',
#  '162.jpg',
#  '174.jpg',
#  '003.jpg',
#  '208.jpg',
#  'images (9).jpg',
#  'download (15).jpg',
#  'images.jpg',
#  '134.jpg',
#  'download (12).jpg',
#  '125.jpg',
#  '116.jpg',
#  '307.jpg',
#  '287.jpg',
#  '317.jpg',
#  'download (2).jpg',
#  '092.jpg',
#  '062.jpg',
#  'download (8).jpg',
#  '319.jpg',
#  '248.jpg',
#  '184.jpg',
#  '089.jpg',
#  '006.jpg',
#  '244.jpg',
#  '180.jpg',
#  '238.jpg',
#  '056.jpg',
#  '315.jpg',
#  '264.jpg',
#  '091.jpg',
#  '124.jpg',
#  '010.jpg',
#  '069.jpg',
#  '172.jpg',
#  '288.jpg',
#  '012.jpg',
#  '028.jpg',
#  '273.jpg',
#  '324.jpg',
#  '230.jpg',
#  '137.jpg',
#  '190.jpg',
#  '027.jpg',
#  'images (12).jpg',
#  '041.jpg',
#  '196.jpg',
#  '074.jpg',
#  '207.jpg',
#  '300.jpg',
#  '164.jpg',
#  '024.JPG',
#  '204.jpg',
#  '004.jpg',
#  '127.jpg',
#  '225.jpg',
#  '195.jpg',
#  '252.jpg',
#  '268.jpg',
#  '261.jpg',
#  '043.jpg',
#  '249.jpg',
#  '011.jpg',
#  '081.jpg',
#  '289.jpg',
#  '058.jpg',
#  'images (3).jpg',
#  '232.jpg',
#  '224.jpg',
#  '214.jpg',
#  '002.jpg',
#  '150.jpg',
#  '033.jpg',
#  '001.jpg',
#  '013.jpg',
#  '129.jpg',
#  '292.jpg',
#  '119.jpg',
#  '227.jpg',
#  '158.jpg',
#  '270.jpg',
#  '283.jpg',
#  '243.jpg',
#  'download (5).jpg',
#  '217.jpg',
#  '272.jpg',
#  '203.jpg',
#  '147.jpg',
#  '109.jpg',
#  'download (1).jpg',
#  '047.jpg',
#  '186.jpg',
#  '234.jpg',
#  '279.jpg',
#  '123.jpg',
#  '171.jpg',
#  'download (6).jpg',
#  '099.jpg',
#  '173.jpg',
#  '039.jpg',
#  '017.jpg',
#  '026.jpg',
#  '042.jpg',
#  '242.jpg',
#  '276.jpg',
#  '301.jpg',
#  '135.jpg',
#  'images (6).jpg',
#  '213.jpg']

# %%
plt.figure(figsize=(5,3))
plt.title('burger')
Baked_potato = plt.imread(training_data_path + '/burger/003.jpg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('butter_naan')
Donut = plt.imread(training_data_path + '/butter_naan/006.jpg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
labels =  ['chai', 'burger', 'butter_naan']

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid,softmax
from tensorflow.keras.applications import VGG16

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3
vgg_model = VGG16(input_shape=(256, 256, 3),
                  weights='imagenet',
                  include_top=False)

# Freeze base model layers so only top layers train
for layer in vgg_model.layers:
    layer.trainable = False

# Flatten and add fully connected layers
x = Flatten()(vgg_model.output)
h1_out = Dense(units=128, kernel_initializer='he_uniform', activation='relu')(x)
h2_out = Dense(units=16, kernel_initializer='he_uniform', activation='relu')(h1_out)

# Final output layer for 3 classes
output = Dense(units=num_classes, kernel_initializer='glorot_uniform', activation='softmax')(h2_out)

# Create the final model
model = Model(inputs=vgg_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
vgg_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 256, 256, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 256, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 128, 128, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 8, 8, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 30s 877ms/step - accuracy: 0.4267 - loss: 1.0174 - val_accuracy: 0.6583 - val_loss: 0.6377
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 751ms/step - accuracy: 0.7269 - loss: 0.5629 - val_accuracy: 0.9167 - val_loss: 0.3347
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 673ms/step - accuracy: 0.9376 - loss: 0.2518 - val_accuracy: 0.9417 - val_loss: 0.2136
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 783ms/step - accuracy: 0.9607 - loss: 0.1292 - val_accuracy: 0.9333 - val_loss: 0.1658
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 836ms/step - accuracy: 1.0000 - loss: 0.0543 - val_accuracy: 0.9667 - val_loss: 0.1250
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 640ms/step - accuracy: 0.9949 - loss: 0.0504 - val_accuracy: 0.9333 - val_loss: 0.1579
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 765ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.9500 - val_loss: 0.1188
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 0.9417 - val_loss: 0.1446
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 746ms/step - accuracy: 1.0000 - loss: 0.0274 - val_accuracy: 0.9333 - val_loss: 0.1326
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 752ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.9500 - val_loss: 0.1042
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 700ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.9417 - val_loss: 0.1621
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 820ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9417 - val_loss: 0.1321
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9750 - val_loss: 0.1208
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 652ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9583 - val_loss: 0.1124
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 804ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.9667 - val_loss: 0.1024
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 779ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.9500 - val_loss: 0.1212
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 769ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9500 - val_loss: 0.1501
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 736ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9500 - val_loss: 0.1307
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 796ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9417 - val_loss: 0.1527
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 689ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9583 - val_loss: 0.1131
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 746ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9500 - val_loss: 0.1422
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 764ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9583 - val_loss: 0.1042
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 645ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9417 - val_loss: 0.1302
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 826ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9333 - val_loss: 0.1424
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 744ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9667 - val_loss: 0.0969
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 642ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9583 - val_loss: 0.1239
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 767ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9583 - val_loss: 0.0975
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 677ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9500 - val_loss: 0.1069
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 723ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9500 - val_loss: 0.1228
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 750ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9583 - val_loss: 0.1228
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 644ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9500 - val_loss: 0.1255
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 785ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9333 - val_loss: 0.1278
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 744ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9417 - val_loss: 0.1120
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 645ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9500 - val_loss: 0.1333
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 751ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9417 - val_loss: 0.1567
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 750ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9583 - val_loss: 0.0830
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 635ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9333 - val_loss: 0.1462
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 744ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9500 - val_loss: 0.1724
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 685ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9500 - val_loss: 0.1256
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 674ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9500 - val_loss: 0.1134
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 755ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9500 - val_loss: 0.1304
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 655ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9250 - val_loss: 0.1197
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 738ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9500 - val_loss: 0.1262
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 750ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9583 - val_loss: 0.1152
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 639ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9417 - val_loss: 0.1161
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 751ms/step - accuracy: 1.0000 - loss: 9.9598e-04 - val_accuracy: 0.9417 - val_loss: 0.1179
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 709ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9583 - val_loss: 0.1057
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 650ms/step - accuracy: 1.0000 - loss: 8.6087e-04 - val_accuracy: 0.9417 - val_loss: 0.1325
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 751ms/step - accuracy: 1.0000 - loss: 8.9987e-04 - val_accuracy: 0.9583 - val_loss: 0.1125
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 655ms/step - accuracy: 1.0000 - loss: 7.5994e-04 - val_accuracy: 0.9500 - val_loss: 0.1060

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['chai', 'burger', 'butter_naan']

# %%
train_input_data.class_indices
# Out:
# {'chai': 0, 'burger': 1, 'butter_naan': 2}

# %%
def fun(path):
    global model, train_input_data

    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # --- 1. Load and preprocess the image ---
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # --- 2. Predict using the model ---
    pred = model.predict(input_image, verbose=0)

    # --- 3. Get class mapping dynamically ---
    # Automatically adapts to whatever classes your train_input_data has
    mapping = train_input_data.class_indices
    inv_map = {v: k for k, v in mapping.items()}

    # --- 4. Get predicted class ---
    predicted_index = int(np.argmax(pred))
    predicted_label = inv_map.get(predicted_index, "Unknown Class")

    # --- 5. Debugging info ---
    print("\nGroup class mapping:", mapping)
    print("Model output probabilities:", np.round(pred, 3))
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}\n")

    # --- 6. Display image with prediction ---
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Split_data/Train/Group_4/burger/002.jpg')
# Out:
# Group class mapping: {'chai': 0, 'burger': 1, 'butter_naan': 2}
# Model output probabilities: [[0. 1. 0.]]
# Predicted class index: 1
# Predicted label: burger

# %%
fun('/content/Split_data/Train/Group_4/butter_naan/002.jpg')
# Out:
# Group class mapping: {'chai': 0, 'burger': 1, 'butter_naan': 2}
# Model output probabilities: [[0. 0. 1.]]
# Predicted class index: 2
# Predicted label: butter_naan

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_4'

# %%
labels = ['chai', 'burger', 'butter_naan']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
y_pred = y_pred.astype(int)
y_true = y_true.astype(int)

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         chai       0.97      0.97      0.97        40
#       burger       0.95      1.00      0.98        40
#  butter_naan       1.00      0.95      0.97        40
#
#     accuracy                           0.97       120
#    macro avg       0.98      0.97      0.97       120
# weighted avg       0.98      0.97      0.97       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.9750

# %%
from tensorflow.keras.models import load_model
model.save('/content/vgg16_group4.h5')
model = load_model('/content/vgg16_group4.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
