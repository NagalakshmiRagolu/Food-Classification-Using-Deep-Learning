# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/INTERNSHIP_VIHARA/PROJECT2/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_2'
validation_data_path = '/content/Split_data/Validation/Group_2'

# %%
os.listdir(training_data_path)
# Out:
# ['Hot Dog', 'Fries', 'Sandwich']

# %%
os.listdir(validation_data_path)
# Out:
# ['Hot Dog', 'Fries', 'Sandwich']

# %%
os.listdir(training_data_path+'/Hot Dog')
# Out:
# ['Hot Dog - Train (1129).jpeg',
#  'Hot Dog - Train (55).jpg',
#  'Hot Dog - Train (8).jpeg',
#  'Hot Dog - Train (1319).jpeg',
#  'Hot Dog - Train (526).jpeg',
#  'Hot Dog - Train (605).jpeg',
#  'Hot Dog - Train (544).jpeg',
#  'Hot Dog - Train (468).jpeg',
#  'Hot Dog - Train (572).jpeg',
#  'Hot Dog - Train (292).jpeg',
#  'Hot Dog - Train (466).jpeg',
#  'Hot Dog - Train (1182).jpeg',
#  'Hot Dog - Train (240).jpeg',
#  'Hot Dog - Train (268).jpeg',
#  'Hot Dog - Train (98).jpg',
#  'Hot Dog - Train (1130).jpeg',
#  'Hot Dog - Train (495).jpeg',
#  'Hot Dog - Train (478).jpeg',
#  'Hot Dog - Train (335).jpeg',
#  'Hot Dog - Train (291).jpeg',
#  'Hot Dog - Train (869).jpeg',
#  'Hot Dog - Train (110).jpg',
#  'Hot Dog - Train (363).jpeg',
#  'Hot Dog - Train (359).jpeg',
#  'Hot Dog - Train (352).jpeg',
#  'Hot Dog - Train (88).jpg',
#  'Hot Dog - Train (1093).jpeg',
#  'Hot Dog - Train (441).jpeg',
#  'Hot Dog - Train (546).jpeg',
#  'Hot Dog - Train (563).jpeg',
#  'Hot Dog - Train (863).jpeg',
#  'Hot Dog - Train (367).jpeg',
#  'Hot Dog - Train (990).jpeg',
#  'Hot Dog - Train (1225).jpeg',
#  'Hot Dog - Train (259).jpeg',
#  '189511.jpg',
#  'Hot Dog - Train (117).jpg',
#  'Hot Dog - Train (434).jpeg',
#  'Hot Dog - Train (28).jpeg',
#  'Hot Dog - Train (1117).jpeg',
#  'Hot Dog - Train (34).jpg',
#  'Hot Dog - Train (737).jpeg',
#  '233179.jpg',
#  'Hot Dog - Train (1055).jpeg',
#  'Hot Dog - Train (630).jpeg',
#  'Hot Dog - Train (111).jpeg',
#  'Hot Dog - Train (567).jpeg',
#  'Hot Dog - Train (233).jpeg',
#  'Hot Dog - Train (941).jpeg',
#  'Hot Dog - Train (557).jpeg',
#  'Hot Dog - Train (1027).jpeg',
#  'Hot Dog - Train (1252).jpeg',
#  'Hot Dog - Train (435).jpeg',
#  'Hot Dog - Train (1153).jpeg',
#  'Hot Dog - Train (871).jpeg',
#  'Hot Dog - Train (598).jpeg',
#  'Hot Dog - Train (809).jpeg',
#  'Hot Dog - Train (768).jpeg',
#  'Hot Dog - Train (616).jpeg',
#  'Hot Dog - Train (32).jpeg',
#  'Hot Dog - Train (656).jpeg',
#  'Hot Dog - Train (569).jpeg',
#  'Hot Dog - Train (901).jpeg',
#  'Hot Dog - Train (704).jpeg',
#  '139177.jpg',
#  'Hot Dog - Train (883).jpeg',
#  'Hot Dog - Train (357).jpeg',
#  'Hot Dog - Train (1174).jpeg',
#  'Hot Dog - Train (161).jpeg',
#  'Hot Dog - Train (1042).jpeg',
#  'Hot Dog - Train (10).jpg',
#  'Hot Dog - Train (1211).jpeg',
#  'Hot Dog - Train (777).jpeg',
#  'Hot Dog - Train (264).jpeg',
#  'Hot Dog - Train (1173).jpeg',
#  'Hot Dog - Train (48).jpg',
#  'Hot Dog - Train (228).jpeg',
#  'Hot Dog - Train (1344).jpeg',
#  'Hot Dog - Train (76).jpg',
#  'Hot Dog - Train (52).jpg',
#  'Hot Dog - Train (864).jpeg',
#  'Hot Dog - Train (713).jpeg',
#  'Hot Dog - Train (447).jpeg',
#  'Hot Dog - Train (826).jpeg',
#  'Hot Dog - Train (968).jpeg',
#  'Hot Dog - Train (596).jpeg',
#  'Hot Dog - Train (651).jpeg',
#  'Hot Dog - Train (137).jpeg',
#  'Hot Dog - Train (114).jpg',
#  'Hot Dog - Train (1108).jpeg',
#  'Hot Dog - Train (970).jpeg',
#  'Hot Dog - Train (997).jpeg',
#  'Hot Dog - Train (543).jpeg',
#  'Hot Dog - Train (1210).jpeg',
#  'Hot Dog - Train (1004).jpeg',
#  'Hot Dog - Train (1065).jpeg',
#  'Hot Dog - Train (769).jpeg',
#  'Hot Dog - Train (304).jpeg',
#  'Hot Dog - Train (141).jpeg',
#  'Hot Dog - Train (1337).jpeg',
#  'Hot Dog - Train (318).jpeg',
#  'Hot Dog - Train (1032).jpeg',
#  '161911.jpg',
#  'Hot Dog - Train (1169).jpeg',
#  'Hot Dog - Train (243).jpeg',
#  'Hot Dog - Train (1328).jpeg',
#  'Hot Dog - Train (5).jpg',
#  'Hot Dog - Train (1168).jpeg',
#  'Hot Dog - Train (987).jpeg',
#  'Hot Dog - Train (690).jpeg',
#  'Hot Dog - Train (707).jpeg',
#  'Hot Dog - Train (130).jpeg',
#  'Hot Dog - Train (1118).jpeg',
#  'Hot Dog - Train (23).jpeg',
#  'Hot Dog - Train (29).jpg',
#  'Hot Dog - Train (831).jpeg',
#  'Hot Dog - Train (832).jpeg',
#  'Hot Dog - Train (209).jpeg',
#  'Hot Dog - Train (480).jpeg',
#  'Hot Dog - Train (433).jpeg']

# %%
os.listdir(training_data_path+'/Sandwich')
# Out:
# ['Sandwich-Train (528).jpeg',
#  'Sandwich-Train (567).jpeg',
#  'Sandwich-Train (110).jpeg',
#  'Sandwich-Train (1087).jpeg',
#  'Sandwich-Train (656).jpeg',
#  'Sandwich-Train (174).jpeg',
#  'Sandwich-Train (305).jpeg',
#  'Sandwich-Train (228).jpeg',
#  'Sandwich-Train (741).jpeg',
#  'Sandwich-Train (1125).jpeg',
#  'Sandwich-Train (530).jpeg',
#  'Sandwich-Train (1104).jpeg',
#  'Sandwich-Train (402).jpeg',
#  'Sandwich-Train (219).jpeg',
#  'Sandwich-Train (917).jpeg',
#  'Sandwich-Train (144).jpeg',
#  'Sandwich-Train (212).jpeg',
#  'Sandwich-Train (1021).jpeg',
#  'Sandwich-Train (609).jpeg',
#  'Sandwich-Train (1262).jpeg',
#  'Sandwich-Train (589).jpeg',
#  'Sandwich-Train (1146).jpeg',
#  'Sandwich-Train (394).jpeg',
#  'Sandwich-Train (1491).jpeg',
#  'Sandwich-Train (1309).jpeg',
#  'Sandwich-Train (1314).jpeg',
#  'Sandwich-Train (232).jpeg',
#  'Sandwich-Train (1354).jpeg',
#  'Sandwich-Train (1046).jpeg',
#  'Sandwich-Train (287).jpeg',
#  'Sandwich-Train (1111).jpeg',
#  'Sandwich-Train (37).jpeg',
#  'Sandwich-Train (1481).jpeg',
#  'Sandwich-Train (913).jpeg',
#  'Sandwich-Train (217).jpeg',
#  'Sandwich-Train (234).jpeg',
#  'Sandwich-Train (634).jpeg',
#  'Sandwich-Train (127).jpeg',
#  'Sandwich-Train (1433).jpeg',
#  'Sandwich-Train (249).jpeg',
#  'Sandwich-Train (784).jpeg',
#  'Sandwich-Train (765).jpeg',
#  'Sandwich-Train (147).jpeg',
#  'Sandwich-Train (399).jpeg',
#  'Sandwich-Train (554).jpeg',
#  'Sandwich-Train (313).jpeg',
#  'Sandwich-Train (1442).jpeg',
#  'Sandwich-Train (701).jpeg',
#  'Sandwich-Train (569).jpeg',
#  'Sandwich-Train (1260).jpeg',
#  'Sandwich-Train (159).jpeg',
#  'Sandwich-Train (1437).jpeg',
#  'Sandwich-Train (1037).jpeg',
#  'Sandwich-Train (541).jpeg',
#  'Sandwich-Train (1280).jpeg',
#  'Sandwich-Train (1463).jpeg',
#  'Sandwich-Train (631).jpeg',
#  'Sandwich-Train (1492).jpeg',
#  'Sandwich-Train (200).jpeg',
#  'Sandwich-Train (12).jpeg',
#  'Sandwich-Train (1428).jpeg',
#  'Sandwich-Train (818).jpeg',
#  'Sandwich-Train (496).jpeg',
#  'Sandwich-Train (164).jpeg',
#  'Sandwich-Train (728).jpeg',
#  'Sandwich-Train (1364).jpeg',
#  'Sandwich-Train (648).jpeg',
#  'Sandwich-Train (312).jpeg',
#  'Sandwich-Train (924).jpeg',
#  'Sandwich-Train (1030).jpeg',
#  'Sandwich-Train (1112).jpeg',
#  'Sandwich-Train (1268).jpeg',
#  'Sandwich-Train (417).jpeg',
#  'Sandwich-Train (1389).jpeg',
#  'Sandwich-Train (323).jpeg',
#  'Sandwich-Train (538).jpeg',
#  'Sandwich-Train (58).jpeg',
#  'Sandwich-Train (1139).jpeg',
#  'Sandwich-Train (1500).jpeg',
#  'Sandwich-Train (1265).jpeg',
#  'Sandwich-Train (1338).jpeg',
#  'Sandwich-Train (911).jpeg',
#  'Sandwich-Train (642).jpeg',
#  'Sandwich-Train (673).jpeg',
#  'Sandwich-Train (710).jpeg',
#  'Sandwich-Train (544).jpeg',
#  'Sandwich-Train (196).jpeg',
#  'Sandwich-Train (1150).jpeg',
#  'Sandwich-Train (33).jpeg',
#  'Sandwich-Train (1141).jpeg',
#  'Sandwich-Train (273).jpeg',
#  'Sandwich-Train (1008).jpeg',
#  'Sandwich-Train (987).jpeg',
#  'Sandwich-Train (709).jpeg',
#  'Sandwich-Train (1308).jpeg',
#  'Sandwich-Train (612).jpeg',
#  'Sandwich-Train (280).jpeg',
#  'Sandwich-Train (1429).jpeg',
#  'Sandwich-Train (1397).jpeg',
#  'Sandwich-Train (1243).jpeg',
#  'Sandwich-Train (370).jpeg',
#  'Sandwich-Train (561).jpeg',
#  'Sandwich-Train (771).jpeg',
#  'Sandwich-Train (411).jpeg',
#  'Sandwich-Train (1426).jpeg',
#  'Sandwich-Train (375).jpeg',
#  'Sandwich-Train (587).jpeg',
#  'Sandwich-Train (1461).jpeg',
#  'Sandwich-Train (854).jpeg',
#  'Sandwich-Train (1360).jpeg',
#  'Sandwich-Train (749).jpeg',
#  'Sandwich-Train (1220).jpeg',
#  'Sandwich-Train (333).jpeg',
#  'Sandwich-Train (979).jpeg',
#  'Sandwich-Train (148).jpeg',
#  'Sandwich-Train (1013).jpeg',
#  'Sandwich-Train (1436).jpeg',
#  'Sandwich-Train (152).jpeg',
#  'Sandwich-Train (997).jpeg',
#  'Sandwich-Train (755).jpeg']

# %%
plt.figure(figsize=(5,3))
plt.title('Fries')
Baked_potato = plt.imread(training_data_path + '/Fries/Fries-Train (1039).jpeg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('Hot dog')
Donut = plt.imread(training_data_path + '/Hot Dog/161911.jpg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
labels =  ['Hot Dog', 'Fries', 'Sandwich']

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid,softmax
from tensorflow.keras.applications import VGG16

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3
vgg_model = VGG16(input_shape=(256, 256, 3),
                  weights='imagenet',
                  include_top=False)

# Freeze base model layers so only top layers train
for layer in vgg_model.layers:
    layer.trainable = False

# Flatten and add fully connected layers
x = Flatten()(vgg_model.output)
h1_out = Dense(units=128, kernel_initializer='he_uniform', activation='relu')(x)
h2_out = Dense(units=16, kernel_initializer='he_uniform', activation='relu')(h1_out)

# Final output layer for 3 classes
output = Dense(units=num_classes, kernel_initializer='glorot_uniform', activation='softmax')(h2_out)

# Create the final model
model = Model(inputs=vgg_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
vgg_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 256, 256, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 256, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 128, 128, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 8, 8, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 352s 30s/step - accuracy: 0.4010 - loss: 1.1124 - val_accuracy: 0.4417 - val_loss: 1.0184
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 354s 30s/step - accuracy: 0.6494 - loss: 0.9092 - val_accuracy: 0.6083 - val_loss: 0.8713
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 0.7678 - loss: 0.6761 - val_accuracy: 0.6750 - val_loss: 0.7954
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 345s 29s/step - accuracy: 0.8651 - loss: 0.4912 - val_accuracy: 0.7417 - val_loss: 0.6599
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 0.8888 - loss: 0.3960 - val_accuracy: 0.7250 - val_loss: 0.6642
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 0.9557 - loss: 0.3071 - val_accuracy: 0.7667 - val_loss: 0.5881
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 0.9645 - loss: 0.2457 - val_accuracy: 0.7833 - val_loss: 0.6610
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 0.9805 - loss: 0.2154 - val_accuracy: 0.7667 - val_loss: 0.6677
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 0.9814 - loss: 0.1876 - val_accuracy: 0.7750 - val_loss: 0.6098
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 0.9857 - loss: 0.1686 - val_accuracy: 0.7667 - val_loss: 0.5697
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 0.9909 - loss: 0.1221 - val_accuracy: 0.7500 - val_loss: 0.6202
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 345s 29s/step - accuracy: 0.9959 - loss: 0.1053 - val_accuracy: 0.7167 - val_loss: 0.6348
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 0.9843 - loss: 0.1178 - val_accuracy: 0.7750 - val_loss: 0.5829
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 0.9944 - loss: 0.0897 - val_accuracy: 0.7667 - val_loss: 0.6108
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 0.9985 - loss: 0.0693 - val_accuracy: 0.8333 - val_loss: 0.5649
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 0.9963 - loss: 0.0703 - val_accuracy: 0.8000 - val_loss: 0.5709
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 0.9991 - loss: 0.0620 - val_accuracy: 0.7833 - val_loss: 0.5640
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 1.0000 - loss: 0.0561 - val_accuracy: 0.7750 - val_loss: 0.5800
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 1.0000 - loss: 0.0535 - val_accuracy: 0.7833 - val_loss: 0.5735
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.7750 - val_loss: 0.6190
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 342s 29s/step - accuracy: 0.9981 - loss: 0.0416 - val_accuracy: 0.7917 - val_loss: 0.6384
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 1.0000 - loss: 0.0436 - val_accuracy: 0.7667 - val_loss: 0.6673
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 1.0000 - loss: 0.0349 - val_accuracy: 0.7750 - val_loss: 0.6452
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 0.9944 - loss: 0.0387 - val_accuracy: 0.7500 - val_loss: 0.5870
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 347s 29s/step - accuracy: 1.0000 - loss: 0.0408 - val_accuracy: 0.8000 - val_loss: 0.5720
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.8083 - val_loss: 0.5852
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.7583 - val_loss: 0.6225
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.7667 - val_loss: 0.6418
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 401s 34s/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.8000 - val_loss: 0.6087
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 399s 34s/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.7667 - val_loss: 0.5897
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 399s 34s/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.8083 - val_loss: 0.6455
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 1.0000 - loss: 0.0201 - val_accuracy: 0.7667 - val_loss: 0.6485
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 345s 29s/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.7833 - val_loss: 0.6176
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 403s 35s/step - accuracy: 0.9977 - loss: 0.0183 - val_accuracy: 0.7667 - val_loss: 0.6208
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 400s 34s/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 0.8000 - val_loss: 0.6240
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 345s 29s/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.8000 - val_loss: 0.7202
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 345s 29s/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.7667 - val_loss: 0.6572
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 347s 30s/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.7833 - val_loss: 0.5707
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 348s 30s/step - accuracy: 0.9944 - loss: 0.0196 - val_accuracy: 0.8000 - val_loss: 0.6151
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.7917 - val_loss: 0.6924
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 343s 29s/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.8000 - val_loss: 0.5987
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.8000 - val_loss: 0.6650
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 344s 29s/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.8000 - val_loss: 0.6539
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 345s 29s/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.7750 - val_loss: 0.6582
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 346s 29s/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.7500 - val_loss: 0.7002
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 349s 30s/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.7833 - val_loss: 0.7704
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 347s 30s/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.7833 - val_loss: 0.6545
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 401s 35s/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.7583 - val_loss: 0.6863
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 349s 30s/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.8000 - val_loss: 0.6182
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 346s 30s/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.8000 - val_loss: 0.6591

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['Hot Dog', 'Fries', 'Sandwich']

# %%
train_input_data.class_indices
# Out:
# {'Hot Dog': 0, 'Fries': 1, 'Sandwich': 2}

# %%
def fun(path):
    global model, train_input_data

    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # --- 1. Load and preprocess the image ---
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # --- 2. Predict using the model ---
    pred = model.predict(input_image, verbose=0)

    # --- 3. Get class mapping dynamically ---
    # Automatically adapts to whatever classes your train_input_data has
    mapping = train_input_data.class_indices
    inv_map = {v: k for k, v in mapping.items()}

    # --- 4. Get predicted class ---
    predicted_index = int(np.argmax(pred))
    predicted_label = inv_map.get(predicted_index, "Unknown Class")

    # --- 5. Debugging info ---
    print("\nGroup class mapping:", mapping)
    print("Model output probabilities:", np.round(pred, 3))
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}\n")

    # --- 6. Display image with prediction ---
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Split_data/Train/Group_1/Crispy Chicken/Crispy Chicken-Train (1053).jpeg')
# Out:
# Group class mapping: {'Hot Dog': 0, 'Fries': 1, 'Sandwich': 2}
# Model output probabilities: [[0.098 0.901 0.001]]
# Predicted class index: 1
# Predicted label: Fries

# %%
fun('/content/Split_data/Test/Group_1/Donut/Donut (1227).jpeg')
# Out:
# Group class mapping: {'Hot Dog': 0, 'Fries': 1, 'Sandwich': 2}
# Model output probabilities: [[0.995 0.004 0.001]]
# Predicted class index: 0
# Predicted label: Hot Dog

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_2'

# %%
labels = ['Hot Dog', 'Fries', 'Sandwich']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 7s/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
y_pred = y_pred.astype(int)
y_true = y_true.astype(int)

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      Hot Dog       0.89      0.82      0.86        40
#        Fries       0.85      0.88      0.86        40
#     Sandwich       0.81      0.85      0.83        40
#
#     accuracy                           0.85       120
#    macro avg       0.85      0.85      0.85       120
# weighted avg       0.85      0.85      0.85       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.8500

# %%
from tensorflow.keras.models import load_model
model.save('/content/vgg16_group2.h5')
model = load_model('/content/vgg16_group2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
