# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_9'
validation_data_path = '/content/Split_data/Validation/Group_9'

# %%
os.listdir(training_data_path)
# Out:
# ['masala_dosa', 'kulfi', 'momos']

# %%
os.listdir(validation_data_path)
# Out:
# ['masala_dosa', 'kulfi', 'momos']

# %%
os.listdir(training_data_path+'/masala_dosa')
# Out:
# ['142.jpg',
#  '021.jpg',
#  '216.jpg',
#  '240.jpg',
#  '266.jpg',
#  'download.jpg',
#  '015.jpg',
#  '063.jpg',
#  '036.jpg',
#  '105.jpg',
#  '265.jpg',
#  '144.jpg',
#  '007.jpg',
#  '020.jpg',
#  '018.jpg',
#  '202.jpg',
#  '003.jpg',
#  '262.jpg',
#  'images.jpg',
#  '235.jpg',
#  '046.jpg',
#  '078.jpg',
#  '307.jpg',
#  '088.jpg',
#  '200.jpg',
#  '297.jpg',
#  '132.jpg',
#  '070.jpg',
#  '092.jpg',
#  '048.jpg',
#  '146.jpg',
#  '111.jpg',
#  '077.jpg',
#  '284.jpg',
#  '278.jpg',
#  '296.jpg',
#  '221.jpg',
#  '251.jpg',
#  '302.jpg',
#  '069.jpg',
#  '049.jpg',
#  '067.jpg',
#  '009.jpg',
#  '012.jpg',
#  'download (3).jpg',
#  'images (15).jpg',
#  'images (2).jpg',
#  '085.jpg',
#  '151.jpg',
#  '190.jpg',
#  '027.jpg',
#  '269.jpg',
#  '188.jpg',
#  '260.jpg',
#  '030.jpg',
#  '161.jpg',
#  'images (7).jpg',
#  'images (12).jpg',
#  '041.jpg',
#  '196.jpg',
#  '101.jpg',
#  '166.jpg',
#  '159.jpg',
#  '204.jpg',
#  '127.jpg',
#  '032.jpg',
#  '295.jpg',
#  '293.jpg',
#  '246.jpg',
#  'images (5).jpg',
#  '194.jpg',
#  '249.jpg',
#  '081.jpg',
#  '169.jpg',
#  '255.jpg',
#  '229.jpg',
#  '094.jpg',
#  '005.jpg',
#  '045.jpg',
#  '155.jpg',
#  '058.jpg',
#  'images (3).jpg',
#  '108.jpg',
#  '224.jpg',
#  '052.jpg',
#  '128.jpg',
#  '002.jpg',
#  'images (8).jpg',
#  '013.jpg',
#  '051.jpg',
#  'images (17).jpg',
#  '129.jpg',
#  '292.jpg',
#  '158.jpg',
#  '270.jpg',
#  '222.jpg',
#  '243.jpg',
#  '182.jpg',
#  'images (19).jpg',
#  '160.jpg',
#  '272.jpg',
#  '031.jpg',
#  'images (1).jpg',
#  'download (1).jpg',
#  '059.jpg',
#  '186.jpg',
#  '165.jpg',
#  '294.jpg',
#  '279.jpg',
#  '226.jpg',
#  '123.jpg',
#  'images (10).jpg',
#  '171.jpg',
#  'download (6).jpg',
#  '275.jpg',
#  '017.jpg',
#  '117.jpg',
#  '271.jpg',
#  '199.jpg',
#  '135.jpg']

# %%
os.listdir(training_data_path+'/momos')
# Out:
# ['254.jpg',
#  '216.jpg',
#  '266.jpg',
#  'download.jpg',
#  '122.jpg',
#  '015.jpg',
#  '175.jpg',
#  '191.jpg',
#  '236.jpg',
#  '036.jpg',
#  '105.jpg',
#  '148.jpg',
#  '192.jpg',
#  '281.jpg',
#  '263.jpg',
#  '087.jpg',
#  '018.jpg',
#  '202.jpg',
#  '162.jpg',
#  '211.jpg',
#  '079.jpg',
#  '197.jpg',
#  '141.jpg',
#  '046.jpg',
#  '206.jpg',
#  '078.jpg',
#  '116.jpg',
#  '200.jpg',
#  'download (7).jpg',
#  '132.jpg',
#  '156.jpg',
#  '210.jpg',
#  '048.jpg',
#  '167.jpg',
#  '022.jpg',
#  '111.jpg',
#  '084.jpg',
#  '089.jpg',
#  '006.jpg',
#  '244.jpg',
#  '251.jpg',
#  '102.jpg',
#  '238.jpg',
#  '315.jpg',
#  '104.jpg',
#  '040.jpg',
#  '067.jpg',
#  '009.jpg',
#  '288.jpg',
#  '233.jpg',
#  '028.jpg',
#  '267.jpg',
#  '230.jpg',
#  '153.jpg',
#  '256.jpg',
#  '151.jpg',
#  '177.jpg',
#  '190.jpg',
#  '304.jpg',
#  '196.jpg',
#  '286.jpg',
#  '164.jpg',
#  '004.jpg',
#  '247.jpg',
#  '032.jpg',
#  '295.jpg',
#  'images (11).jpg',
#  '293.jpg',
#  '246.jpg',
#  '130.jpg',
#  '261.jpg',
#  '068.jpg',
#  '249.jpg',
#  '183.jpg',
#  '169.jpg',
#  '076.jpg',
#  '255.jpg',
#  '237.jpg',
#  '083.jpg',
#  '187.jpg',
#  '258.jpg',
#  '055.jpg',
#  '044.jpg',
#  '058.jpg',
#  '212.jpg',
#  '108.jpg',
#  '232.jpg',
#  '052.jpg',
#  '072.jpg',
#  '214.jpg',
#  '290.jpg',
#  '150.jpg',
#  '013.jpg',
#  'images (17).jpg',
#  '064.jpg',
#  '181.jpg',
#  '241.jpg',
#  '035.jpg',
#  '243.jpg',
#  'download (5).jpg',
#  '066.jpg',
#  '218.jpg',
#  '168.jpg',
#  '285.jpg',
#  'images (1).jpg',
#  '147.jpg',
#  'download (1).jpg',
#  '047.jpg',
#  '186.jpg',
#  '282.jpg',
#  '024.jpg',
#  '257.jpg',
#  'images (10).jpg',
#  '275.jpg',
#  '017.jpg',
#  '176.jpg',
#  '242.jpg',
#  '135.jpg',
#  '213.jpg',
#  'images (14).jpg']

# %%
plt.figure(figsize=(5,3))
plt.title('masala_dosa')
Baked_potato = plt.imread(training_data_path + '/masala_dosa/030.jpg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('kulfi')
Donut = plt.imread(training_data_path + '/kulfi/002.jpg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
labels =  ['masala_dosa', 'kulfi', 'momos']

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid,softmax
from tensorflow.keras.applications import VGG16

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3
vgg_model = VGG16(input_shape=(256, 256, 3),
                  weights='imagenet',
                  include_top=False)

# Freeze base model layers so only top layers train
for layer in vgg_model.layers:
    layer.trainable = False

# Flatten and add fully connected layers
x = Flatten()(vgg_model.output)
h1_out = Dense(units=128, kernel_initializer='he_uniform', activation='relu')(x)
h2_out = Dense(units=16, kernel_initializer='he_uniform', activation='relu')(h1_out)

# Final output layer for 3 classes
output = Dense(units=num_classes, kernel_initializer='glorot_uniform', activation='softmax')(h2_out)

# Create the final model
model = Model(inputs=vgg_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
vgg_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 256, 256, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 256, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 128, 128, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 8, 8, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.5213 - loss: 0.9634 - val_accuracy: 0.7833 - val_loss: 0.6378
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8566 - loss: 0.4529 - val_accuracy: 0.7833 - val_loss: 0.4706
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 17s 745ms/step - accuracy: 0.9193 - loss: 0.2582 - val_accuracy: 0.8167 - val_loss: 0.3886
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 888ms/step - accuracy: 0.9530 - loss: 0.1707 - val_accuracy: 0.8250 - val_loss: 0.3767
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 702ms/step - accuracy: 0.9808 - loss: 0.1029 - val_accuracy: 0.8417 - val_loss: 0.3671
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 829ms/step - accuracy: 0.9942 - loss: 0.0782 - val_accuracy: 0.8667 - val_loss: 0.3559
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 804ms/step - accuracy: 0.9897 - loss: 0.0596 - val_accuracy: 0.8333 - val_loss: 0.3939
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 758ms/step - accuracy: 0.9988 - loss: 0.0474 - val_accuracy: 0.8167 - val_loss: 0.3943
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 715ms/step - accuracy: 0.9952 - loss: 0.0445 - val_accuracy: 0.8500 - val_loss: 0.3426
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 864ms/step - accuracy: 1.0000 - loss: 0.0333 - val_accuracy: 0.8583 - val_loss: 0.3507
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 760ms/step - accuracy: 1.0000 - loss: 0.0259 - val_accuracy: 0.8500 - val_loss: 0.3554
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 664ms/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.8667 - val_loss: 0.3253
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 787ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.8417 - val_loss: 0.3524
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 728ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.8750 - val_loss: 0.3397
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 707ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.8833 - val_loss: 0.2693
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 791ms/step - accuracy: 0.9957 - loss: 0.0205 - val_accuracy: 0.8750 - val_loss: 0.3507
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 693ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.8583 - val_loss: 0.3195
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 748ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.8750 - val_loss: 0.2925
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 786ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8583 - val_loss: 0.3625
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 664ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.8417 - val_loss: 0.3534
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 767ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8583 - val_loss: 0.2961
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 785ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8667 - val_loss: 0.3264
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 670ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.8583 - val_loss: 0.3116
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 783ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8583 - val_loss: 0.3366
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 782ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.8833 - val_loss: 0.3272
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 667ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.8667 - val_loss: 0.3171
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 773ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.8250 - val_loss: 0.3175
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 948ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8583 - val_loss: 0.3397
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 655ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8500 - val_loss: 0.3366
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 774ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8667 - val_loss: 0.3803
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 788ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8833 - val_loss: 0.2892
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 671ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8667 - val_loss: 0.3423
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 784ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8667 - val_loss: 0.3637
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 793ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8667 - val_loss: 0.3986
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 681ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8667 - val_loss: 0.3627
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 779ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8750 - val_loss: 0.3467
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 944ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8833 - val_loss: 0.3665
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 680ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8500 - val_loss: 0.3198
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 775ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8750 - val_loss: 0.3473
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 790ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8833 - val_loss: 0.3449
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 677ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8500 - val_loss: 0.3685
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 792ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8833 - val_loss: 0.3095
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 787ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8750 - val_loss: 0.3329
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 666ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8750 - val_loss: 0.3318
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 780ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8917 - val_loss: 0.3213
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 750ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8667 - val_loss: 0.3474
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 706ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8583 - val_loss: 0.3509
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 847ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8583 - val_loss: 0.3855
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 772ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8833 - val_loss: 0.3137
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 677ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8833 - val_loss: 0.3354

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['masala_dosa', 'kulfi', 'momos']

# %%
train_input_data.class_indices
# Out:
# {'masala_dosa': 0, 'kulfi': 1, 'momos': 2}

# %%
def fun(path):
    global model, train_input_data

    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # --- 1. Load and preprocess the image ---
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # --- 2. Predict using the model ---
    pred = model.predict(input_image, verbose=0)

    # --- 3. Get class mapping dynamically ---
    # Automatically adapts to whatever classes your train_input_data has
    mapping = train_input_data.class_indices
    inv_map = {v: k for k, v in mapping.items()}

    # --- 4. Get predicted class ---
    predicted_index = int(np.argmax(pred))
    predicted_label = inv_map.get(predicted_index, "Unknown Class")

    # --- 5. Debugging info ---
    print("\nGroup class mapping:", mapping)
    print("Model output probabilities:", np.round(pred, 3))
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}\n")

    # --- 6. Display image with prediction ---
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Split_data/Train/Group_9/kulfi/005.jpg')
# Out:
# Group class mapping: {'masala_dosa': 0, 'kulfi': 1, 'momos': 2}
# Model output probabilities: [[0. 1. 0.]]
# Predicted class index: 1
# Predicted label: kulfi

# %%
fun('/content/Split_data/Train/Group_9/masala_dosa/005.jpg')
# Out:
# Group class mapping: {'masala_dosa': 0, 'kulfi': 1, 'momos': 2}
# Model output probabilities: [[1. 0. 0.]]
# Predicted class index: 0
# Predicted label: masala_dosa

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_9'

# %%
labels = ['masala_dosa', 'kulfi', 'momos']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
y_pred = y_pred.astype(int)
y_true = y_true.astype(int)

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#  masala_dosa       0.86      0.90      0.88        40
#        kulfi       0.86      0.90      0.88        40
#        momos       1.00      0.90      0.95        40
#
#     accuracy                           0.90       120
#    macro avg       0.90      0.90      0.90       120
# weighted avg       0.90      0.90      0.90       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.9000

# %%
from tensorflow.keras.models import load_model
model.save('/content/vgg16_group9.h5')
model = load_model('/content/vgg16_group9.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
