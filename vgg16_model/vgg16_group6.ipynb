# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/Split_data

# %%
# !unzip -q '/content/drive/MyDrive/Split_data.zip' -d /content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

# %%
training_data_path =  '/content/Split_data/Train/Group_6'
validation_data_path = '/content/Split_data/Validation/Group_6'

# %%
os.listdir(training_data_path)
# Out:
# ['dhokla', 'chole_bhature', 'dal_makhani']

# %%
os.listdir(validation_data_path)
# Out:
# ['dhokla', 'chole_bhature', 'dal_makhani']

# %%
os.listdir(training_data_path+'/dhokla')
# Out:
# ['157.jpg',
#  '216.jpg',
#  '240.jpg',
#  'download.jpg',
#  '122.jpg',
#  '063.jpg',
#  '096.jpg',
#  '191.jpg',
#  '061.jpg',
#  '036.jpg',
#  '131.jpg',
#  '105.jpg',
#  '139.jpg',
#  '144.jpg',
#  '007.jpg',
#  '263.jpg',
#  '087.jpg',
#  '120.jpg',
#  '018.jpg',
#  '162.jpg',
#  '025.jpg',
#  '003.jpg',
#  'images (9).jpg',
#  '065.jpg',
#  '250.jpg',
#  '079.jpg',
#  '134.jpg',
#  '046.jpg',
#  '078.jpg',
#  '071.jpg',
#  '008.jpg',
#  '179.jpg',
#  '116.jpg',
#  'images (4).jpg',
#  '088.jpg',
#  'download (7).jpg',
#  '220.jpg',
#  '132.jpg',
#  'download (2).jpg',
#  '070.jpg',
#  '167.jpg',
#  '022.jpg',
#  '006.jpg',
#  '056.jpg',
#  '170.jpg',
#  '124.jpg',
#  '010.jpg',
#  '040.jpg',
#  '049.jpg',
#  '067.jpg',
#  '172.jpg',
#  '288.jpg',
#  '012.jpg',
#  'download (3).jpg',
#  '126.jpg',
#  '085.jpg',
#  '230.jpg',
#  '073.jpg',
#  '280.jpg',
#  '093.jpg',
#  '190.jpg',
#  '188.jpg',
#  '260.jpg',
#  '030.jpg',
#  '161.jpg',
#  '112.jpg',
#  '041.jpg',
#  '140.jpg',
#  '207.jpg',
#  '101.jpg',
#  '164.jpg',
#  '029.jpg',
#  '247.jpg',
#  'images (11).jpg',
#  '130.jpg',
#  '198.jpg',
#  '261.jpg',
#  '118.jpg',
#  '054.jpg',
#  'images (5).jpg',
#  '113.jpg',
#  '043.jpg',
#  '249.jpg',
#  '183.jpg',
#  '076.jpg',
#  '154.jpg',
#  '255.jpg',
#  '187.jpg',
#  '055.jpg',
#  '044.jpg',
#  '058.jpg',
#  'images (3).jpg',
#  '232.jpg',
#  '052.jpg',
#  '072.jpg',
#  '002.jpg',
#  '150.jpg',
#  '001.jpg',
#  '013.jpg',
#  '064.jpg',
#  '181.jpg',
#  '243.jpg',
#  '016.jpg',
#  '037.jpg',
#  '218.jpg',
#  '285.jpg',
#  '147.jpg',
#  '186.jpg',
#  '097.jpg',
#  '024.jpg',
#  '279.jpg',
#  '257.jpg',
#  'images (10).jpg',
#  '099.jpg',
#  '017.jpg',
#  '117.jpg',
#  '042.jpg',
#  '189.jpg',
#  '271.jpg',
#  '135.jpg']

# %%
os.listdir(training_data_path+'/dal_makhani')
# Out:
# ['142.jpg',
#  'download.jpg',
#  '038.jpg',
#  '015.jpg',
#  '061.jpg',
#  '139.jpg',
#  '143.jpg',
#  '192.jpg',
#  '265.jpg',
#  '007.jpg',
#  '316.jpg',
#  '120.jpg',
#  '025.jpg',
#  '174.jpg',
#  '003.jpg',
#  '303.jpg',
#  '208.jpg',
#  'images (9).jpg',
#  '219.jpg',
#  '079.jpg',
#  '197.jpg',
#  '134.jpg',
#  '206.jpg',
#  '307.jpg',
#  'images (4).jpg',
#  '287.jpg',
#  '200.jpg',
#  'download (7).jpg',
#  '205.jpg',
#  '317.jpg',
#  '132.jpg',
#  '320.jpg',
#  '092.jpg',
#  '062.jpg',
#  '048.jpg',
#  '075.jpg',
#  '138.jpg',
#  '319.jpg',
#  '146.jpg',
#  '248.jpg',
#  '111.jpg',
#  '084.jpg',
#  '278.jpg',
#  '244.jpg',
#  '223.jpg',
#  '102.jpg',
#  '238.jpg',
#  '315.jpg',
#  '040.jpg',
#  '049.jpg',
#  '009.jpg',
#  '172.jpg',
#  '288.jpg',
#  'download (3).jpg',
#  '028.jpg',
#  '085.jpg',
#  '230.jpg',
#  '153.jpg',
#  '256.jpg',
#  '312.jpg',
#  '073.jpg',
#  '280.jpg',
#  '188.jpg',
#  '304.jpg',
#  '103.jpg',
#  '030.jpg',
#  '161.jpg',
#  'images (7).jpg',
#  '196.jpg',
#  '074.jpg',
#  '100.jpg',
#  '086.jpg',
#  '185.jpg',
#  '101.jpg',
#  '166.jpg',
#  '159.jpg',
#  '204.jpg',
#  '004.jpg',
#  '246.jpg',
#  '252.jpg',
#  '130.jpg',
#  '198.jpg',
#  '259.jpg',
#  '068.jpg',
#  '133.jpg',
#  '183.jpg',
#  '083.jpg',
#  '299.jpg',
#  '212.jpg',
#  '108.jpg',
#  '052.jpg',
#  '214.jpg',
#  '002.jpg',
#  '001.jpg',
#  '064.jpg',
#  '181.jpg',
#  '158.jpg',
#  '035.jpg',
#  '314.jpg',
#  'download (5).jpg',
#  '272.jpg',
#  '203.jpg',
#  '285.jpg',
#  '109.jpg',
#  '047.jpg',
#  '024.jpg',
#  '294.jpg',
#  '012.JPG',
#  '279.jpg',
#  '226.jpg',
#  '123.jpg',
#  'images (10).jpg',
#  '171.jpg',
#  'download (6).jpg',
#  '173.jpg',
#  '039.jpg',
#  '017.jpg',
#  '042.jpg',
#  '199.jpg',
#  'images (14).jpg']

# %%
plt.figure(figsize=(5,3))
plt.title('dal_makhani')
Baked_potato = plt.imread(training_data_path + '/dal_makhani/007.jpg')
plt.imshow(Baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('chole_bhature')
Donut = plt.imread(training_data_path + '/chole_bhature/011.jpg')
plt.imshow(Donut)
plt.show()

# %% [markdown]
# **Image Data Augumentation**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
training_set = ImageDataGenerator(rescale = 1 / 255,
                                  rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

validation_set = ImageDataGenerator(rescale = 1 / 255,rotation_range = 0.2,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
labels =  ['dhokla', 'chole_bhature', 'dal_makhani']

# %%
train_input_data = training_set.flow_from_directory(training_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)

val_input_data = validation_set.flow_from_directory(validation_data_path,
                                 classes = labels,
                                 target_size=(256,256),
                                 class_mode = 'categorical',
                                 batch_size = 30)
# Out:
# Found 360 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.activations import relu,sigmoid,softmax
from tensorflow.keras.applications import VGG16

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model architecture
#
# model = Sequential()
#
# # 1st Filter (or) Hidden layer
# model.add(Conv2D(64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='valid', strides=1, input_shape=(256,256,3)))
#
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 2nd Filter (or) Hidden layer
# model.add(Conv2D(32 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 3rd Filter (or) Hidden layer
# model.add(Conv2D(8 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# # 4th Filter (or) Hidden layer
# model.add(Conv2D(4 , kernel_size = (3,3), kernel_initializer='he_uniform',padding='valid',strides = 1))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
#
# model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='he_uniform',activation='relu'))
# model.add(Dense(2,kernel_initializer='he_uniform',activation='relu'))
#
# model.add(Dense(1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
num_classes = 3
vgg_model = VGG16(input_shape=(256, 256, 3),
                  weights='imagenet',
                  include_top=False)

# Freeze base model layers so only top layers train
for layer in vgg_model.layers:
    layer.trainable = False

# Flatten and add fully connected layers
x = Flatten()(vgg_model.output)
h1_out = Dense(units=128, kernel_initializer='he_uniform', activation='relu')(x)
h2_out = Dense(units=16, kernel_initializer='he_uniform', activation='relu')(h1_out)

# Final output layer for 3 classes
output = Dense(units=num_classes, kernel_initializer='glorot_uniform', activation='softmax')(h2_out)

# Create the final model
model = Model(inputs=vgg_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
vgg_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 256, 256, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 256, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 128, 128, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 8, 8, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_input_data,
    epochs=50,
    validation_data=val_input_data
)
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 924ms/step - accuracy: 0.4725 - loss: 1.0593 - val_accuracy: 0.6250 - val_loss: 0.7952
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 767ms/step - accuracy: 0.7953 - loss: 0.6246 - val_accuracy: 0.7417 - val_loss: 0.6292
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 672ms/step - accuracy: 0.8660 - loss: 0.4322 - val_accuracy: 0.8083 - val_loss: 0.6074
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 880ms/step - accuracy: 0.9140 - loss: 0.3109 - val_accuracy: 0.8417 - val_loss: 0.4495
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 763ms/step - accuracy: 0.9532 - loss: 0.2163 - val_accuracy: 0.8583 - val_loss: 0.4036
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 741ms/step - accuracy: 0.9786 - loss: 0.1601 - val_accuracy: 0.8750 - val_loss: 0.3230
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 816ms/step - accuracy: 0.9847 - loss: 0.1108 - val_accuracy: 0.9083 - val_loss: 0.3194
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 761ms/step - accuracy: 0.9926 - loss: 0.0933 - val_accuracy: 0.9083 - val_loss: 0.2728
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 704ms/step - accuracy: 0.9972 - loss: 0.0741 - val_accuracy: 0.8750 - val_loss: 0.3001
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 679ms/step - accuracy: 0.9950 - loss: 0.0561 - val_accuracy: 0.8917 - val_loss: 0.2988
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 767ms/step - accuracy: 0.9993 - loss: 0.0485 - val_accuracy: 0.9083 - val_loss: 0.2899
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 664ms/step - accuracy: 1.0000 - loss: 0.0462 - val_accuracy: 0.9000 - val_loss: 0.2672
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 737ms/step - accuracy: 1.0000 - loss: 0.0404 - val_accuracy: 0.8833 - val_loss: 0.2757
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 772ms/step - accuracy: 0.9981 - loss: 0.0374 - val_accuracy: 0.9000 - val_loss: 0.2568
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 655ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.8917 - val_loss: 0.2539
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 779ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.9083 - val_loss: 0.2737
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.9083 - val_loss: 0.2357
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 764ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.8917 - val_loss: 0.2740
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 678ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.8667 - val_loss: 0.3068
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 773ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.9167 - val_loss: 0.2497
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 794ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.9000 - val_loss: 0.2252
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 678ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9333 - val_loss: 0.2294
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 775ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.8917 - val_loss: 0.2547
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 786ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9167 - val_loss: 0.2171
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 659ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9083 - val_loss: 0.2177
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 763ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.8917 - val_loss: 0.2481
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 818ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.8917 - val_loss: 0.2856
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 691ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8917 - val_loss: 0.2747
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 774ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9083 - val_loss: 0.2598
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 941ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9167 - val_loss: 0.1874
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 665ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.8917 - val_loss: 0.2813
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 755ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9083 - val_loss: 0.2549
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 776ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9250 - val_loss: 0.2199
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 676ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8917 - val_loss: 0.2551
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 770ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9083 - val_loss: 0.2373
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 779ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8917 - val_loss: 0.2675
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 672ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9167 - val_loss: 0.2299
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 769ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8917 - val_loss: 0.2523
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 716ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8833 - val_loss: 0.2439
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 678ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8917 - val_loss: 0.2974
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 787ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9167 - val_loss: 0.2391
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 687ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9000 - val_loss: 0.2309
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 699ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9250 - val_loss: 0.2045
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 758ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9167 - val_loss: 0.2224
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 659ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9167 - val_loss: 0.2467
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 763ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9167 - val_loss: 0.2563
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 755ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9083 - val_loss: 0.2198
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 665ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9000 - val_loss: 0.2991
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 769ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9250 - val_loss: 0.2420
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 775ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9000 - val_loss: 0.2630

# %% [markdown]
# **test_model**

# %%
import cv2

# %%
labels
# Out:
# ['dhokla', 'chole_bhature', 'dal_makhani']

# %%
train_input_data.class_indices
# Out:
# {'dhokla': 0, 'chole_bhature': 1, 'dal_makhani': 2}

# %%
def fun(path):
    global model, train_input_data

    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # --- 1. Load and preprocess the image ---
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {path}")

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(img_rgb, (256, 256))
    normalized = resized / 255.0
    input_image = np.expand_dims(normalized, axis=0)

    # --- 2. Predict using the model ---
    pred = model.predict(input_image, verbose=0)

    # --- 3. Get class mapping dynamically ---
    # Automatically adapts to whatever classes your train_input_data has
    mapping = train_input_data.class_indices
    inv_map = {v: k for k, v in mapping.items()}

    # --- 4. Get predicted class ---
    predicted_index = int(np.argmax(pred))
    predicted_label = inv_map.get(predicted_index, "Unknown Class")

    # --- 5. Debugging info ---
    print("\nGroup class mapping:", mapping)
    print("Model output probabilities:", np.round(pred, 3))
    print(f"Predicted class index: {predicted_index}")
    print(f"Predicted label: {predicted_label}\n")

    # --- 6. Display image with prediction ---
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_label}")
    plt.show()

# %%
fun('/content/Split_data/Train/Group_6/dal_makhani/003.jpg')
# Out:
# Group class mapping: {'dhokla': 0, 'chole_bhature': 1, 'dal_makhani': 2}
# Model output probabilities: [[0. 0. 1.]]
# Predicted class index: 2
# Predicted label: dal_makhani

# %%
fun('/content/Split_data/Train/Group_6/chole_bhature/005.jpg')
# Out:
# Group class mapping: {'dhokla': 0, 'chole_bhature': 1, 'dal_makhani': 2}
# Model output probabilities: [[0.    0.999 0.001]]
# Predicted class index: 1
# Predicted label: chole_bhature

# %%
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
test_data_path = '/content/Split_data/Test/Group_6'

# %%
labels = ['dhokla', 'chole_bhature', 'dal_makhani']

# %%
test_set = ImageDataGenerator(rescale=1./255)

test_input_data = test_set.flow_from_directory(
    test_data_path,
    classes=labels,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=10,
    shuffle=False
)
# Out:
# Found 120 images belonging to 3 classes.

# %%
test_input_data.reset()
predictions = model.predict(test_input_data, verbose=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_input_data.classes

# %%
y_pred = y_pred.astype(int)
y_true = y_true.astype(int)

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_input_data.class_indices.keys())))
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#        dhokla       1.00      0.95      0.97        40
# chole_bhature       0.93      0.93      0.93        40
#   dal_makhani       0.93      0.97      0.95        40
#
#      accuracy                           0.95       120
#     macro avg       0.95      0.95      0.95       120
#  weighted avg       0.95      0.95      0.95       120

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.9500

# %%
from tensorflow.keras.models import load_model
model.save('/content/vgg16_group6.h5')
model = load_model('/content/vgg16_group6.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
